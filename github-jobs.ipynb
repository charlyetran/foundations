# %% [markdown]
# ## Introduction
# In order to do Data Science we have to be able to gather data. Oftentimes we get data from an API, sometimes from a database. This Jupyter notebook we'll guide you through a project that will involve getting data from an API, storing it in a relational database and performing some SQL queries to do some basic data analysis.
#
# Our API of choice for this project will be [GitHub Jobs](https://jobs.github.com). Besides being simple to use, it could be a useful resource to job-hunt.

# %% [markdown]
# ## Assingment
# - Get acquainted with the GitHub Jobs web interface and read through their API page.
# - Import the Requests package and call the API with the parameters of your choice.
# - Print the status code to make sure it went well.

# %%
import requests

url = "https://jobs.github.com/positions.json"
search_term = 'data_science'

params = {'description': search_term}
response = requests.get(url, params=params)

# %%
import json

# %%
print(json.dumps(response.json(), sort_keys=True,indent=4))
# Out:
# [
#     {
#         "company": "Leadpages",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/012e2336-d389-11e6-867c-d25a8523294d.png",
#         "company_url": "http://www.leadpages.net/",
#         "created_at": "Thu Jan 05 21:04:49 UTC 2017",
#         "description": "<p>We promise you haven\u2019t worked with anyone <a href=\"http://www.leadpages.net/careers\">like us</a> before.  We\u2019re a Minneapolis / St. Paul, MN based startup that\u2019s changing the way businesses do marketing, lead generation, and conversion rate optimization online.  With a growing team that works closely together, we move fast and enjoy what we do. </p>\n\n<p>As a <strong>Cloud Engineer / Site Reliability Engineer</strong>, you&#39;ll work with a dynamic team to help build out and manage our cloud infrastructure and deployment pipelines. You\u2019ll partner with development teams to build and support tooling - specializing in centralized logging, monitoring and alerting. You will also develop a strong familiarity with all aspects of our overall architecture, including Javascript front-ends, Python API microservices, and Scala-based data science backends. There\u2019s nothing boring about this position!</p>\n\n<p>Come join the fun and build something great with us!</p>\n\n<p><strong>What you\u2019ll do:</strong></p>\n\n<p>Your day-to-day responsibilities will shift and grow but to start with, you will:</p>\n\n<ul>\n<li>Help manage our virtualized cloud infrastructure in the Google Cloud stack: App Engine, Container Engine (Kubernetes), Compute Engine, Cloud Datastore, Cloud Storage, Cloud SQL and BigQuery. Some familiarity with this stack or similar would be amazing!</li>\n<li>Automate application deployment and infrastructure creation processes with Jenkins, Ansible, Packer, Terraform and the Docker toolkit. Again, if you have hands-on experience with these tools or something similar, this could be your jam</li>\n<li>Think laterally and collaborate with other teams to work through tough challenges</li>\n<li>Craft awesome solutions while taking the needs of multiple areas of the organization into account</li>\n<li>Push back and voice your opinion if you think differently from the rest of the team. Yep! We truly value your opinion and we want to hear it</li>\n<li>Work within the fast-paced, lean startup environment, knowing it means we ship early and often.</li>\n<li>Watch what you\u2019ve made help your teammates create awesome customer value. This is what it\u2019s all about!</li>\n</ul>\n\n<p><strong>What you\u2019ve done:</strong></p>\n\n<p>You have a unique combination of skills, talents, and mindset, including:</p>\n\n<ul>\n<li>Experience with building and scaling complex application systems</li>\n<li>A background in scripted provisioning/configuration management tools (think Bash, Ansible, Packer, Terraform, Fabric, and similar)</li>\n<li>Familiarity with Docker and container-based building, deployment, orchestration and service discovery</li>\n<li>Building release pipelines using CI/CD tooling like Jenkins</li>\n<li>Experience with open source monitoring and logging, such as Prometheus, Elasticsearch, Logstash, Kibana and Grafana</li>\n<li>A solid understanding of Unix-like operating systems, Ubuntu/Debian in particular</li>\n<li>Proven development ability; you\u2019re confident with writing and testing robust software</li>\n<li>Strong interpersonal skills and the ability to clearly communicate with both technical and business team members</li>\n</ul>\n\n<p><strong>Who you are:</strong></p>\n\n<ul>\n<li>You are a tech and tooling enthusiast; you love staying up-to-date with the latest solutions for deploying and managing cloud infrastructure</li>\n<li>You build beautifully bulletproof systems that others can depend on, but you also dabble with prototypes and experimental new solutions</li>\n<li>You love improving the intelligence of various systems and environments through the implementation of sturdy and searchable monitoring and centralized logging</li>\n<li>You always look for new things to learn and new ways to leverage your knowledge. You would take great pride in becoming a Subject Matter Expert people can trust</li>\n<li>You have a passion for collaboration with software dev ...
#         "how_to_apply": "<p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter explaining why you feel you are a match for this position <a href=\"http://careers.leadpages.net/apply/YN38C7/Cloud-Engineer-Site-Reliability-Engineer?source=Github\">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n",
#         "id": "806cba3a-d38a-11e6-9b37-19faf2d9fe5b",
#         "location": "Minneapolis, MN",
#         "title": "Cloud Engineer / Site Reliability Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/806cba3a-d38a-11e6-9b37-19faf2d9fe5b"
#     },
#     {
#         "company": "University of California, Berkeley",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/7a1dae50-d37b-11e6-8a62-e48674991ce0.png",
#         "company_url": "http://www.berkeley.edu",
#         "created_at": "Thu Jan 05 19:17:40 UTC 2017",
#         "description": "<p>POSITION ANNOUNCEMENT\nUNIVERSITY OF CALIFORNIA, BERKELEY</p>\n\n<p>Data Services Librarian\nHiring Range: Associate Librarian to Librarian\n$58,400- $84,930 per annum, based upon qualifications This is a full-time appointment available starting May 2017.</p>\n\n<p>The University of California, Berkeley seeks a collaborative and service-oriented librarian to join a team of specialists supporting world-class research and teaching. The Data Services Librarian develops, leads, and assesses an innovative outreach and service program to increase data and statistical literacy within the Library and across the curriculum.</p>\n\n<p>The Environment\nThe UC Berkeley Library is an internationally renowned research and teaching facility at one of the nation&#39;s premier public universities. A highly diverse and intellectually rich environment, Berkeley serves a campus community of 25,500 undergraduate students, 10,300 graduate students, and 1,500 faculty. With a collection of more than 11 million volumes and a collections budget of over $15 million, the Library offers extensive collections in all formats and robust services to connect users with those collections and build their related research skills.</p>\n\n<p>The Library\u2019s Social Sciences Division consists of five library locations \u2013 the Anthropology Library, Business Library, Data Lab, Environmental Design Library, and Social Research Library \u2013 and collections and services located in Doe Library/Gardner MAIN Stacks. Collectively, the staff \u2013 12 librarians, 12 library staff, and over 50 student library employees \u2013 support the research, teaching, and study needs of a diverse clientele. These libraries are primary service points and provide research-level print and digital collections in several languages to support the research and teaching programs of several academic programs and centers, professional schools, research units, and the general public. Visit <a href=\"http://www.lib.berkeley.edu/\">http://www.lib.berkeley.edu/</a> for more information about the UC Berkeley Library.</p>\n\n<p>Responsibilities\nReporting to the Head of the Library\u2019s Social Sciences Division, the incumbent provides leadership for campus and library initiatives supporting data and digital scholarship, and works with a variety of ad-hoc and standing groups to help achieve program objectives. The Data Services Librarian is the library liaison to the undergraduate Data Science Education Program (DSEP) and to the broader Data Science Initiative at Berkeley. The Data Science Initiative is University-wide, supporting the increased use of computational and inferential thinking in many academic disciplines and professional schools and developing information literacies for a data-rich world. The librarian establishes strong relationships with faculty and students, conducts analysis and assessment of user and program data needs, develops and implements peer consulting/drop-in services, provides virtual and in-person research consultations, creates instructional materials in a variety of formats, promotes library resources and services, and works collaboratively and programmatically to support data literacy across the curriculum.</p>\n\n<p>The incumbent works closely with a network of campus partners including the Social Sciences Data Laboratory (D-Lab), the Social Science Matrix, the Berkeley Institute for Transparency in the Social Sciences (BITSS), the Berkeley Institute for Data Science (BIDS) and the Research Data Management Core Team, as well as colleagues within the Library, including those who support GIS, qualitative data, and the digital humanities. The librarian provides advice, guidance and instruction to build capacity amongst colleagues and to better use quantitative data to assess and improve Library services. The librarian is the service lead to the Library\u2019s Data Acquisition and Access Program (DAAP), providing input and advice on data re ...
#         "how_to_apply": "<p><a href=\"http://apptrkr.com/940483\">http://apptrkr.com/940483</a></p>\n",
#         "id": "812add76-d37b-11e6-8065-d8a87983108a",
#         "location": "Berkeley, CA 94720",
#         "title": "Data Services Librarian",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/812add76-d37b-11e6-8065-d8a87983108a"
#     },
#     {
#         "company": "HHMI Janelia Research Campus",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/81a49ffc-d291-11e6-9919-6d19904950ce.jpg",
#         "company_url": "https://www.janelia.org/",
#         "created_at": "Wed Jan 04 16:32:23 UTC 2017",
#         "description": "<p>About HHMI:</p>\n\n<pre><code>Howard Hughes Medical Institute (HHMI) is a science philanthropy whose\nmission is to advance biomedical research and science education for the\nbenefit of humanity. We empower exceptional scientists and students to\npursue fundamental questions about living systems, and work to share\nscientific discoveries with researchers, students, and science-curious\nindividuals around the world.\n\nFounded in 1953 by aviator and industrialist Howard R. Hughes, HHMI is\nheadquartered in Chevy Chase, Maryland, and employs more than 2,500 people\nacross the U.S. Visit hhmi.org/careers to learn more about working at HHMI.\n</code></pre>\n\n<p>About Janelia:</p>\n\n<pre><code>Janelia Research Campus is a pioneering research center in Ashburn,\nVirginia, where scientists pursue fundamental questions in neuroscience and\nimaging. The Howard Hughes Medical Institute (HHMI) launched Janelia in\n2006, establishing an intellectually distinctive environment for scientists\nto do creative, collaborative, hands-on work. To learn more about working at\nJanelia, visit janelia.org/careers.\n</code></pre>\n\n<p>Summary:</p>\n\n<pre><code>Within a time-limited (twelve to eighteen month) collaborative project\nbetween the Allen Institute for Brain Science and Janelia Research Campus\n(HHMI) we seek a software engineer/consultant to facilitate the processing\nof high-throughput serial section transmission electron microscopy data into\ndistortion free volumes for reconstruction of neural connectivity. The\nsoftware engineer/consultant will be working with engineers at both the\nAllen Institute for Brain Science and the Howard Hughes Medical Institute\n(Janelia Research Campus) in Ashburn, VA. The position is based in Ashburn,\nVA, and some travel is expected.\n</code></pre>\n\n<p>Role:</p>\n\n<ul>\n<li>Design and production of end-to-end data flow pipeline for large scale image\nregistration </li>\n<li>Expand existing Java and Matlab libraries </li>\n<li>Wrapping the pipeline as a service - Documenting and administering individual components </li>\n<li>Training other production engineers and scientists to use and expand the pipeline</li>\n</ul>\n\n<p>Principal Responsibilities:</p>\n\n<ul>\n<li>Will work closely with scientists &amp; software engineers to oversee infrastructure for\nmanipulating peta-scale electron microscopy data </li>\n<li>Will work on automation of existing image data registration, processing and curation </li>\n<li>Diagnose and troubleshoot,both independently and collaboratively </li>\n<li>Evaluate &amp; learn new software tools, practices &amp; algorithms</li>\n</ul>\n\n<p>Preferred Qualifications: </p>\n\n<ul>\n<li> B.S. or M.S. in Computer Science or related field (or equivalent education and experience) </li>\n<li> Strong familiarity with Linux </li>\n<li> Proficient in Java </li>\n<li> Preferred: Experience with utilizing SQL and/or NoSQL data stores (e.g. MongoDB,\nPostgreSQL) </li>\n<li>  Preferred: Experience with image processing (ImageJ, Fiji or other) </li>\n<li>Preferred: Experience with Matlab -  Familiar with RESTful web services </li>\n<li>Experience using Spark on an HPC cluster </li>\n<li> Comfortable working with new programming languages and tools when necessary</li>\n</ul>\n\n<p>HHMI is an Equal Opportunity Employer.</p>\n",
#         "how_to_apply": "<p>Please apply online at <a href=\"http://bit.ly/2iPnHKb\">http://bit.ly/2iPnHKb</a>.</p>\n",
#         "id": "cdb81090-d291-11e6-9fc6-230a387788dd",
#         "location": "Ashburn, VA",
#         "title": "Image Processing Software Developer and Production Engineer (JAVA) Consultant ",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/cdb81090-d291-11e6-9fc6-230a387788dd"
#     },
#     {
#         "company": "Brinker International",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/1c00c4b6-d1c2-11e6-9d77-70a0c115d478.png",
#         "company_url": "http://www.brinkerjobs.com",
#         "created_at": "Tue Jan 03 14:39:33 UTC 2017",
#         "description": "<p>Senior Software Engineer  </p>\n\n<p>Dallas, TX (North Dallas) </p>\n\n<p>What does it mean to be a BrinkerHead? We play like a team, take pride in our culture and seek every opportunity to make people feel special. Life is short. Work happy. At Brinker, we connect, serve and give to create the best life for our Team Members, Guests and community. Through our cultural beliefs, Brinker empowers its Team Members to positively impact our 4 Key Results: Engaging Team Members, Bringing Back Guests, Growing Sales and Increasing Profits. </p>\n\n<p>Job Summary </p>\n\n<p>Brinker is seeking an experienced Senior Software Engineer - Technical Lead to be part of the IT Digital Marketing team, supporting loyalty and personalization development.  This role will work with business, IT and vendor partners on a multi-year roadmap within the Digital Guest Experience program. This program consists of projects across many channels and customer touch points, and will enable Brinker to deliver a robust and relevant Guest Experience within our corporate and franchise locations. Key areas include loyalty,  social monitoring and engagement systems, guest engagement features delivered through tabletop devices,  personalization system utilized to streamline inbound and outbound customer experiences through all guest engagement channels, guest relations, and integration with website and mobile applications. </p>\n\n<p>Your Key Job Functions </p>\n\n<p>\u2022Actively contribute to the development of Brinker&#39;s personalization offerings, partnership development, and technical roadmaps for a market leading personalization experience. </p>\n\n<p>\u2022Support personalization capability development collaborating with other Brinker team members and our partner marketing agencies to transform and integrate their systems. </p>\n\n<p>\u2022Collaborate with architects, engineers and 3rd party partners to develop conceptual architecture and physical design for Marketing applications including loyalty, campaign and engagement management systems. </p>\n\n<p>\u2022Provide inputs to project plan (tasks and estimates) for technical design, development, testing, deploy and post-production warranty. </p>\n\n<p>\u2022Work with Delivery Lead and Project Manager to plan work for self and other engineers. </p>\n\n<p>\u2022Partner with business analysts, solution architects, SMEs, and other IT team members to establish the technical vision and examine tradeoffs between usability and performance needs.</p>\n\n<p>\u2022Collaborate with other application teams to define and implement any required interfaces for Marketing applications including various communication and engagement channels (e.g. web, mobile, table top device, social). </p>\n\n<p>\u2022Develop technical designs to meet business requirements, and review the technical designs of other engineers. </p>\n\n<p>\u2022Provide technical leadership through all phases of the projects, including design </p>\n\n<p>The successful candidate will be able to demonstrate and bring to life the Brinker cultural beliefs to drive our 4 key results: </p>\n\n<p>Feedback\u2019s Priceless                     I see more through your feedback. </p>\n\n<p>Own it                                                   I own, drive and achieve key results. </p>\n\n<p>Win Together                                   I work across boundaries to achieve key results. </p>\n\n<p>Trust Matters                                   I act in a manner that cultivates trust in others. </p>\n\n<p>Thinking Forward                             I think and act in a manner to deliver desired future results. </p>\n\n<p>What You Bring to the Team  </p>\n\n<p>\u2022BS/BA degree or Information Systems, Computer Science or related field preferred, or equivalent formal training or work experience. </p>\n\n<p>\u2022Strong SDLC experience and application architecture/design background. </p>\n\n<p>\u2022At least 5 years experience as a Technical Lead ...
#         "how_to_apply": "<p>Email your resume to <a href=\"mailto:terry.snodgrass@brinker.com\">terry.snodgrass@brinker.com</a>.</p>\n",
#         "id": "4847ca1a-d1c2-11e6-87c7-f7105d23b2fa",
#         "location": "Dallas, Texas",
#         "title": "Senior Software Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/4847ca1a-d1c2-11e6-87c7-f7105d23b2fa"
#     },
#     {
#         "company": "Paf",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/71c4e220-d0f9-11e6-982f-8ee5a9eb085a.png",
#         "company_url": "https://www.paf.com/about-us",
#         "created_at": "Mon Jan 02 14:42:36 UTC 2017",
#         "description": "<p>The Database Development Team at Paf is responsible for the development of data management (including data warehousing) and the BI tools, providing stakeholders and other teams like Compliance, Analytics, CRM and Customer Communications with the data required for daily operations as well as long term business development.</p>\n\n<p>We are now looking for Senior Database Developer to strengthen the team. In this role you will be involved in the whole development life cycle from analysis and design to development and testing of our Internet business. You will also work with our experienced DB/DW professionals with various tasks and work related activities around database development, Big Data and Middleware products.</p>\n\n<p>Requirements:</p>\n\n<ul>\n<li>Degree in Computer Science or in information Processing Science development.</li>\n<li>5+ years of proven experience in Oracle PL/SQL.</li>\n<li>Experience in SQL tuning and optimization.</li>\n<li>Experience in OLTP Database design.</li>\n<li>Experience with DW design.</li>\n<li>5+ years of troubleshooting experience of database queries, reports.</li>\n</ul>\n\n<p>To your advantage:</p>\n\n<ul>\n<li>Basic knowledge of software development and data access layer design.</li>\n<li>Knowledge of DW principles and/or working with large data sets.</li>\n<li>Experience of Analytics and Big Data technologies.</li>\n<li>Experience with data warehouse or large data sets</li>\n</ul>\n\n<p>Your personal qualities:</p>\n\n<ul>\n<li>Strong analytical and problem-solving skills</li>\n<li>A good communicator with customer oriented approach</li>\n<li>Proven collaborative skills and ability to work well within a team</li>\n<li>Self-motivated with critical attention to detail, deadlines and reporting</li>\n</ul>\n\n<p>Good knowledge in English (written and spoken) is a requirement since our corporate language is English.</p>\n\n<p>Are you interested?</p>\n\n<p>Please submit your application online at <a href=\"http://bit.ly/2iZLxGd\">http://bit.ly/2iZLxGd</a> by 23rd January 2017 the latest. All communication and applications will be treated confidentially. For more information about the position, please contact our recruitment partner Arja Martikainen, +358 407621564 or arja.martikainen(at)barona.fi.</p>\n",
#         "how_to_apply": "<p>Please apply online at <a href=\"http://bit.ly/2iZLxGd\">http://bit.ly/2iZLxGd</a> or email your resume to arja.martikainen(at)barona.fi</p>\n",
#         "id": "98f2edec-d0f9-11e6-8897-553ed26979e3",
#         "location": "Helsinki, Finland",
#         "title": "Senior Database Developer \u2013 Oracle PL/SQL",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/98f2edec-d0f9-11e6-8897-553ed26979e3"
#     },
#     {
#         "company": "Gram Games",
#         "company_logo": null,
#         "company_url": "http://gram.gs/",
#         "created_at": "Thu Dec 29 22:55:48 UTC 2016",
#         "description": "<p>Rev up those engines; let\u2019s see what this baby can do. Millions of hits? Psh. You could do that in your sleep.</p>\n\n<p>Essentially...</p>\n\n<p>In a perfect world, it would always be smooth sailing, and none of our engines or infrastructures would need fixing. But it\u2019s not a perfect world, and it\u2019s rarely smooth sailing, so we need a backend developer. You\u2019re the guy standing there with a wrench and a toolbox, ready to fix any backend problems as they crop up. Your responsibility is to develop and maintain everything that lies behind the scenes, everything that keeps us chugging along. As a senior developer, you\u2019ll also be expected to be a resource for those around you on issues of backend development - our go-to guy.</p>\n\n<p>In essence, a Senior Backend developer is responsible for the backbone of our technical infrastructure - an infrastructure that processes billions of data points and serves millions of players, and consistently ensures the highest standard of player experience. The tools and systems you develop will be integral to our continued ability to function at ever-increasing levels.</p>\n\n<p>We&#39;re looking for someone who...</p>\n\n<p>...has at least 5+ years experience in backend game development</p>\n\n<p>...has a Bsc in Computer Science or Computer Engineering</p>\n\n<p>...has strong database design skills</p>\n\n<p>...is experienced with Go, Java, Python, Redis, Linux, VCS, AWS stack and components</p>\n\n<p>...is experienced with launching games and determining specifications</p>\n\n<p>...has a strong understanding of both relational and nonrelational databases</p>\n\n<p>...is able to design and construct the framework needed to implement features</p>\n\n<p>...is able to think in an abstract and modular way</p>\n\n<p>...is fanatically passionate about code reuse</p>\n\n<p>...is able to deliver high quality, structured code, demonstrating attention to detail and design</p>\n\n<p>...has excellent problem solving skills</p>\n\n<p>...is self-motivated and a self-starter</p>\n\n<p>...has proficient written and oral English</p>\n\n<p>...has excellent teamwork skills</p>\n\n<p>It would also be great if you...</p>\n\n<p>...had an MSc or PhD in relevant engineering fields</p>\n\n<p>...are experienced with developing systems for synchronous and/or asynchronous multiplayer games</p>\n\n<p>...are familiar with HTML, CSS, Javascript, Bash</p>\n\n<p>...are experienced in web protocols, application servers, NoSQL, Unity, queues, in-memory caches/databases</p>\n\n<p>...are familiar with development of mobile free-to-play games and mobile best practices</p>\n",
#         "how_to_apply": "<p><a href=\"http://grnh.se/8oknja1\">http://grnh.se/8oknja1</a></p>\n",
#         "id": "e5ed5520-ce19-11e6-91ed-8e7aa8839a6b",
#         "location": "London, UK ",
#         "title": "Senior Backend Developer (London, UK)",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/e5ed5520-ce19-11e6-91ed-8e7aa8839a6b"
#     },
#     {
#         "company": "Gram Games",
#         "company_logo": null,
#         "company_url": "http://gram.gs/",
#         "created_at": "Thu Dec 29 22:53:22 UTC 2016",
#         "description": "<p>Come on board and develop mind blowing games for millions of players around the planet. What are you waiting for?</p>\n\n<p>Essentially...</p>\n\n<p>As a developer here, your responsibilities would include, among others, working on our internal development framework, rapidly prototyping new game concepts, and working closely with our design, art, data science, and marketing teams to create the next (or next ten) big mobile hit(s). You\u2019d be expected to be proactive, and to act as a fount of knowledge when it comes to game development. We&#39;re looking for candidates who won&#39;t balk at a challenge, whether it be wrangling the code of large, third-party codebases, or implementing features that will, when published, affect millions of people around the world. Simply put, we&#39;re looking for someone with the passion for both building great games, and shipping great code.</p>\n\n<p>We&#39;re looking for someone who...</p>\n\n<p>...has at least 5+ years experience as a game developer</p>\n\n<p>...has previous experience working with mobile games, as well as a proven track-record.</p>\n\n<p>...has previously shipped at least one product.</p>\n\n<p>...has a solid understanding of the Unity 3D game engine.</p>\n\n<p>...can code in C# with the best of them.</p>\n\n<p>...has a solid understanding of game development related design patterns.</p>\n\n<p>...is very comfortable with modern version control systems (git)</p>\n\n<p>...is competent with general game development concepts, including graphics development, game logic, communication with backend services, user interface development, and artificial intelligence.</p>\n\n<p>...has strong communication skills, regardless of the team member\u2019s technical proficiency</p>\n\n<p>...designs, architects, and implements high quality, structured, and robust code.</p>\n\n<p>\u2026can independently create quality solutions to problems.</p>\n\n<p>...can quickly, and efficiently, pick up and start working with pre-existing codebases.</p>\n\n<p>...is proficient at written and spoken English.</p>\n\n<p>It would also be great if you...</p>\n\n<p>...have previous exposure to the Free-to-Play model.</p>\n\n<p>...have a BSc in Game Development/Computer Science/Computer Engineering</p>\n\n<p>...have some knowledge of Python, Objective-C, Swift, and Java.</p>\n\n<p>...are familiar with more complex parts of software development, such as writing unit tests, using continuous integration, and working with backends (parsing json, using Web sockets, encryption, etc.)</p>\n\n<p>...are someone who builds games in their free time, or takes part in recreational game development opportunities such as Game Jams or Hackathons</p>\n",
#         "how_to_apply": "<p><a href=\"http://grnh.se/0ogf1d1\">http://grnh.se/0ogf1d1</a></p>\n",
#         "id": "8b8135b6-ce19-11e6-991b-57bf66b1b809",
#         "location": "London, UK ",
#         "title": "Senior Developer (London, UK)",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/8b8135b6-ce19-11e6-991b-57bf66b1b809"
#     },
#     {
#         "company": "Enza Zaden Beheer B.V.",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/af433b70-c914-11e6-93d6-c9c4d6d8e9dd.jpg",
#         "company_url": "http://www.enzazaden.nl/aboutus/",
#         "created_at": "Fri Dec 23 13:43:54 UTC 2016",
#         "description": "<p><strong>Bioinformatician</strong><br />\n<em>Unravelling data</em><br />\n<em>The Netherlands, Enkhuizen &ndash; full time at least at MSc level</em><br />\n<br />\n<strong>Department</strong><br />\nThe Biotechnology Research department consists of about 80 persons and performs a wide range of research. This research generates vast amounts of data, ready to be analysed. The goal of this analysis is to facilitate the breeding process by finding leads which will enable the breeders to create the best vegetable varieties.<br />\n<br />\n<strong>What are you going to do?</strong><br />\nAs bioinformatician you will analyse research data. You will work in close collaboration with molecular biologists and your main focus will be on next-generation sequencing data. This includes setting up of analysis pipelines, data visualisation and optimising in-house developed algorithms. Additionally you will employ statistical learning and data mining techniques to uncover patterns in biological data and/or (fully) automate existing workflows. As part of a multidisciplinary team you are also expected to assist and support your colleagues in bioinformatics-related issues.<br />\n<br />\n<strong>Your power</strong><br />\nYou are familiar with the standard programming languages, such as Java, and your enthusiasm for programming has led you to explore other languages as well. You have the drive to dig into a complex data-set and the ability to continue until you have found the answers you are looking for. You keep looking for new possibilities and you share your ideas with the team. Furthermore you have excellent communication skills and are a strong team player.&nbsp;<br />\n<br />\n<strong>Requirements</strong></p>\n\n<ul>\n    <li><strong>MSc </strong>or <strong>PhD degree</strong> in <strong>bioinformatics</strong>, <strong>computer science</strong> or <strong>data analysis</strong> related field.&nbsp;</li>\n    <li>Interested in plant biology</li>\n    <li>Confident in a scripting language such as <strong>Perl </strong>or <strong>Python</strong>.&nbsp;</li>\n    <li>Able to work in a <strong>Linux</strong>-based environment</li>\n    <li>You preferably have knowledge on source code version control (git), high performance computing and sequence data analysis.&nbsp;</li>\n    <li>Basic database knowledge and web application development (Perl Mojolicious/ Python flask) are a plus.</li>\n</ul>\n\n<p><br />\n<strong>Our power</strong><br />\nWe are an independent vegetable seed company, breeding, producing and marketing our varieties all over the world. There&#39;s a good chance that you&#39;ll find our tomatoes, cucumbers, sweet peppers, lettuce or other vegetables on your plate, no matter where you are.<br />\n<br />\nWe are a company with a supportive, energetic culture. As an employee of Enza Zaden, you&rsquo;ll have more than 1700 colleagues of 40 nationalities worldwide. Strong team players with an entrepreneurial spirit who easily take responsibilities is exactly what we like to see in our employees here at Enza Zaden. Please visit our website for more information about our organisation: <a href=\"https://ltpx.nl/j7EG82e\" target=\"_blank\"><strong>www.enzazaden.com</strong></a>.<br />\n<br />\n<strong>Are you going to join us?</strong><br />\nWe offer you a positive working environment and ample opportunities for personal development. Plus a competitive salary and excellent benefits.<br />\n<br />\nFor more information please contact Femke Koning, HR Manager, phone +31 (0)228 350 100.<br />\n<br />\n<em>Acquisition by third parties is not appreciated.</em><br />\n&nbsp;</p>\n\n<p><em>Trefwoorden: bioinformaticus, bio informaticus, bio-informatica</em> <img alt=\"\" src=\"https://bcontrol.brockmeyer.nl/track.php?orderid=22493\" style=\"height:0;width:0\" /></p>\n",
#         "how_to_apply": "<p><a href=\"https://ltpx.nl/f1ScFz6\" target=\"_self\">Please point your application to the HR department.</a></p>\n",
#         "id": "b5a334f2-c914-11e6-91a9-98a048782382",
#         "location": "Enkhuizen",
#         "title": "Bioinformatician",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/b5a334f2-c914-11e6-91a9-98a048782382"
#     },
#     {
#         "company": "Squla",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/f1b17772-c849-11e6-86d1-f29a738c9252.png",
#         "company_url": "https://squla.redirect.your-jobresponse.com/f/125745/V819/apply",
#         "created_at": "Thu Dec 22 13:25:17 UTC 2016",
#         "description": "<p><b>Squla - Full Stack Developer</b><br>\nFull-time in Amsterdam</p>\n\n<p><b>Does the idea of making the world a better place appeal to you?</b><br>\nMore specifically, do you find it fascinating and fun to build a web platform for educational games where hundreds of thousands of children, parents and teachers will interact? In different countries, with different content, and in different languages!</p>\n\n<p>Still reading? Good, let\u2019s dive into more details.</p>\n\n<p><b>Your role</b><br>\nIn this role you will get the opportunity to work within a team of great developers who build the Squla platform. This platform includes educational missions and quizzes for our students, features for teachers and parents who can follow the progress of the students and send motivational messages, and a shop for parents.</p>\n\n<p><b>Your typical day at work will involve:</b><br></p>\n\n<ul>\n<li>building end-to-end features that contribute to both the growth of the Squla brand internationally, and the engagement of our target groups;<br></li>\n<li>testing your features and being fully responsible for them when they go live;<br></li>\n<li>working across the different projects we have, in Python, Html5, WordPress (PHP), Java;<br></li>\n<li>planning and estimating your work;<br></li>\n<li>trouble-shooting live issues that could be functional bugs or performance bottlenecks.</li>\n</ul>\n\n<p><b>Who are we looking for?</b><br>\nWe are looking for a person who has non-trivial experience in a variety of programming languages,\nboth dynamic and statically typed. One who:<br></p>\n\n<ul>\n<li>understands and appreciates the differences between different programming languages and is flexible to work in the languages we use here (Python, PHP, Java, and JavaScript to name the major ones);<br></li>\n<li>is able to get things done and who has a \u2018can do\u2019 positive attitude;<br></li>\n<li>has a pragmatic approach to problem solving;<br></li>\n<li>is a team player, able to communicate across different functional teams, and not just with their technical colleagues;<br></li>\n<li>loves to take ownership and responsibility to put their features live independently;<br></li>\n<li>understands e-commerce requirements and is able to formulate optimal solutions for the growth and international expansion of the Squla brand.</li>\n</ul>\n\n<p><b>Your background</b><br></p>\n\n<ul>\n<li>Bachelors\u2019 or Masters\u2019 degree in computer science or a related field;<br></li>\n<li>2+ years\u2019 experience in software development;<br></li>\n<li>Exceptional analytical and problem-solving skills;<br></li>\n<li>Thorough knowledge of computer science fundamentals (algorithms and data structures);<br></li>\n<li>Good foundation in relational database concepts and practices;<br></li>\n<li>Ability to write good quality code which is clean and maintainable, following standards and guidelines;<br></li>\n<li>Good understanding of separation of concerns, MVC pattern of development;<br></li>\n<li>Experience writing automated tests for your code;</li>\n</ul>\n\n<p><b>Optional nice to have\u2019s:</b><br></p>\n\n<ul>\n<li>Amazon Web Services experience \u2013 at least a knowledge of what services are available for what purposes, and how to access them;\u2028<br></li>\n<li>Experience with HTML5 games.</li>\n</ul>\n\n<p>\u2028<b>How do we work?</b><br>\nIn a team of 9 developers, working closely with product owners and business owners, using agile scrum methodology with 2-week sprints.</p>\n\n<p><b>Why you want to work with us</b><br>\nThe Squla office is located in a beautiful office on Weesperplein in central Amsterdam. We work hard, play hard and we have a lot of fun and foster an informal yet professional atmosphere. </p>\n\n<p>The Squla crew is a dynamic team that is enthusiastic about creating a fun, new way of learning in this ever-evolving digital age. We believe that a positive and energetic, yet relaxed, work environment not only encour ...
#         "how_to_apply": "<p>You can apply for this position by clicking <b><a href=\"https://squla.redirect.your-jobresponse.com/full_stack_developer_amsterdam/125745/V819/apply\">here</a></b>!</p>\n",
#         "id": "f8b12752-c849-11e6-8707-480d66a7fe46",
#         "location": "Amsterdam",
#         "title": "Full Stack Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/f8b12752-c849-11e6-8707-480d66a7fe46"
#     },
#     {
#         "company": "FEI Company",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/eff9f2f4-c828-11e6-9a8e-f97395899781.jpg",
#         "company_url": "http://www.fei.com",
#         "created_at": "Thu Dec 22 09:29:53 UTC 2016",
#         "description": "<p><B>Software Engineer - Camera team - Transmission electron microscopy</p>\n\n<p>The Company, pushing the boundaries of discovery</b><BR>\nWith more than 60 years of innovation and leadership, FEI Company enables customers to find meaningful answers to questions that accelerate breakthrough discoveries, increase productivity, and ultimately change the world. FEI designs, manu\u00adfactures, and supports the broadest range of high-performance microscopy workflows that provide images and answers in the micro-, nano-, and picometer scales. </p>\n\n<p>Combining hardware and software expertise in electron, ion, and light microscopy with deep application knowledge in the materials science, life sci\u00adences, electronics, and natural resources markets, the worldwide FEI team of 2,700+ employees is dedicated to customers&#39; pursuit of discovery and resolution to global challenges.</p>\n\n<p><B>Introduction, the World needs answers</b><BR>\nIf you want to help accelerate discoveries that change our world for the better, look no further than FEI. We are looking for motivated and inspired professionals with experience to strengthen our R&amp;D software organization. We are devoted to bringing leading technologies to different markets with high quality products and services. The markets we service are Science (Life Sciences &amp; Materials Science) and Industry (Oil &amp; Gas and Semiconductor)</p>\n\n<p><B>Check out these video\u2019s</b><BR></p>\n\n<ul>\n<li>FEI\u2019s corporate organization <a href=\"https://www.youtube.com/watch?v=ABSxT6Y099I\">https://www.youtube.com/watch?v=ABSxT6Y099I</a><BR></li>\n<li>FEI\u2019s life sciences business <a href=\"https://www.youtube.com/watch?v=KxfPTJt1NEA\">https://www.youtube.com/watch?v=KxfPTJt1NEA</a><BR></li>\n<li>Inside the FEI Titan Transmission Electron Microscope <a href=\"https://www.youtube.com/watch?v=2wEmsDh_l_A\">https://www.youtube.com/watch?v=2wEmsDh_l_A</a><BR></li>\n<li>Blog SW Technical lead Eindhoven <a href=\"http://www.talentbox.nl/blogs/3/gl6zc7-achieve-breakthroughs-by-electron-microscopes-\">http://www.talentbox.nl/blogs/3/gl6zc7-achieve-breakthroughs-by-electron-microscopes-</a><BR></li>\n<li>Blog SW engineer Eindhoven <a href=\"http://www.brainporttalentbox.com/blogs/3/iwdy98-building-software-related-applications-for-electron-microscopes-\">http://www.brainporttalentbox.com/blogs/3/iwdy98-building-software-related-applications-for-electron-microscopes-</a></li>\n</ul>\n\n<p><B>The Corporate Technology Software Group</b><BR>\nA part of the R&amp;D organization is the Corporate Technology Software Group. \nThis group is responsible for the development of the platform and microscope control software for Transmission Electron Microscopes (TEM), like cameras and imaging software\nThis group is committed to bring value-adding and game changing software solutions to our customers that help them with their success. The application software group is a multi-site development organization divided over the R&amp;D sites in Eindhoven (the Netherlands), Brno (Czech), and Russia. The organization in Eindhoven consists of around 50 software engineers. </p>\n\n<p><B>Position</b><BR>\nThe software engineer will be part of an enthusiastic team. You will be responsible for the full software development cycle of new features, product enhancement and new applications. Your assignment will be a mixture of the following activities:<BR></p>\n\n<ul>\n<li>Software specification based on system performance and requirements<BR></li>\n<li>Develop designs based on a full comprehension of the function, purpose and application of the product.<BR></li>\n<li>Align on architectural guidelines and re-use of components with other engineers<BR></li>\n<li>Contribute to the architectural software roadmap using the sw product roadmaps and vision. Implement and integrate while making practical development choices given limited design information and defined delivery schedules.<BR></li ...
#         "how_to_apply": "<p><a href=\"https://feicompany.redirect.your-jobresponse.com/software_engineer_camera_team_transmission_electron_microscopy_eindhoven/125673/V819/apply\">Click here for the application form!</a></p>\n",
#         "id": "fb370efe-c828-11e6-94be-fb480120aa94",
#         "location": "Eindhoven",
#         "title": "Software Engineer - Camera team - Transmission electron microscopy",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/fb370efe-c828-11e6-94be-fb480120aa94"
#     },
#     {
#         "company": "ASML",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/b6faf4f0-c759-11e6-98b8-a78c2551b38f.jpg",
#         "company_url": "http://www.asml.com",
#         "created_at": "Wed Dec 21 08:48:28 UTC 2016",
#         "description": "<p><b>Pragmatic Researcher (PhD)</b></p>\n\n<p><i>Join us in re-shaping the boundaries of science and technology.</i></p>\n\n<p>ASML is always searching for brilliant minds. That&#39;s why we will host a unique event on 16th (evening), 17th and 18st of March 2017: the ASML PhD Master Class.</p>\n\n<p>During the PhD Master Class, we will be showcasing some of the fascinating and extreme technology challenges that we are currently facing. You will experience our way of doing things and get a strong impression of the ASML culture.</p>\n\n<p>For three days, we invite you to use your &quot;brilliant mind&quot; in a team-based workshop aimed at cracking those challenges. We will also be setting up personal exploration interviews to get you acquainted with ASML and you will meet peers from all over the world.</p>\n\n<p>For this event, we are looking for PhD students in the last phase of study, or those with a maximum of two years of experience in the working field related to:</p>\n\n<ul>\n<li>(Applied) Physics / Astronomy</li>\n<li>Computer Science / Embedded Systems / Artificial Intelligence / Data Science / Information Technology / Computational Science / Software Engineering</li>\n<li>(Applied) Mathematics</li>\n<li>(Physical) Chemistry / Chemical Engineering</li>\n<li>Material Sciences</li>\n<li>Mechanical Engineering</li>\n<li>Mechatronics / Systems &amp; Control</li>\n<li>Electrical Engineering</li>\n<li>Aerospace Engineering</li>\n<li>Nanotechnology / Nanoscience / Nanomaterials</li>\n</ul>\n\n<p><b>A great opportunity for a brilliant mind</b><br>\nOne of the reasons why ASML has already attracted some of the world&#39;s best minds is the very nature of what we do; the ICs that we help to make impact on every level of society. You could say that we help to make healthcare systems more affordable for example or transport systems greener and more energy-efficient. You could also say that we make education more accessible to everyone. We make these things happen because microchips are at the heart of all electronic things, and we create the machines that not only help making microchips, but our creative technology continues to make them smaller, faster and cheaper. And having an impact on almost every aspect of modern human life is a challenge that talented people seem to rise up to with enthusiasm.</p>\n\n<p><b>This is more than just a career opportunity; it&#39;s a chance to make a real difference.</b><br>\nHendrik Hans (26) from Medan (Indonesia): &quot;My ideas about ASML changed totally. I was amazed about the nanotechnology that is involved in the production of chips. Without ever smaller components, we would still be walking around with cell phones in size shoebox.&quot;</p>\n\n<p><b>Selection process</b><br>\nUnfortunately we are limited in the number of participants for the PhD Master Class. Therefore we will review your registration according to the following process:</p>\n\n<ul>\n<li>Application deadline January 10th 12:00PM. Applications should include a resume with contact information, GPA&#39;s and publications (optional in scientific appendix).</li>\n<li>First selection round: we will inform you about the outcome of the CV review January 20th.</li>\n<li>If you are through to the second round, we will ask you to record a video motivation as a preparation for the next selection round (technical matching board).Deadline for recording is January 27th.</li>\n<li>Second selection round: your resume and motivation video will be reviewed by a technical matching board. We will inform you about the final outcome February 14th.</li>\n</ul>\n\n<p>To get an impression of the 2016 PhD Master Class; please watch this short video (2 minutes). And just go to <a href=\"http://www.asml.com/masterclass\">www.asml.com/masterclass</a> to register.</p>\n\n<p>Apply online via <a href=\"https://asml.redirect.your-jobresponse.com/pragmatic_researcher_phd_veldhoven/125409/V819/apply\">this link!!</a></p>\n\n<p><b><i>A ...
#         "how_to_apply": "<p><a href=\"https://asml.redirect.your-jobresponse.com/pragmatic_researcher_phd_veldhoven/125409/V819/apply\">Click here to apply</a></p>\n",
#         "id": "d8afc95e-c759-11e6-8b92-55c03f089c66",
#         "location": "Veldhoven",
#         "title": "Pragmatic Researcher (PhD)",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/d8afc95e-c759-11e6-8b92-55c03f089c66"
#     },
#     {
#         "company": "Trusted Autonomy",
#         "company_logo": null,
#         "company_url": null,
#         "created_at": "Mon Dec 19 20:54:05 UTC 2016",
# ...
#         "how_to_apply": "<p><a href=\"mailto:contact@devicetools.ch\">contact@devicetools.ch</a></p>\n",
#         "id": "d1d69600-c108-11e6-9365-5be7e5886d40",
#         "location": "Zurich",
#         "title": "Software/DevOps Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/d1d69600-c108-11e6-9365-5be7e5886d40"
#     },
#     {
#         "company": "The Nordam Group",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/f53d44ee-be25-11e6-957a-f616239dc5c8.png",
#         "company_url": "http://nordam.com/",
#         "created_at": "Fri Dec 09 15:42:07 UTC 2016",
#         "description": "<p>Onsite, Relocation available.</p>\n\n<p>We\u2019re an independent development team inside The NORDAM Group building a brand new public web service. The aerospace industry we\u2019re modernizing has yet to fully benefit from the data revolution. We pride ourselves on our \u201cstartup\u201d approach: we leverage modern technologies and methodologies and we prefer results over tradition. By being a totally separate unit in a large corporation, we benefit from its support and extensive business network, without all the downsides that come with software development at larger companies.</p>\n\n<p>You&#39;ll be responsible for leading a team of developers. This position will work on virtually all aspects of the product and will help drive product and technology strategy. You&#39;ll be designing solutions to complex or unusual problems or assignments requiring considerable ingenuity and judgement.</p>\n\n<p>Our product needs to handle information at scale, safely. We deal with items often worth tens of thousands of dollars or more. We do things the right way from the first time - cutting corners is not worth it in our case.</p>\n\n<p>You know Ruby inside and out, both the pretty and the ugly. You can tell when a piece of code will be inefficient just by looking at it and you know how to optimize it.</p>\n\n<p>As an early dev hire, you will be in a unique position to work on virtually all aspects of our product and have a strong voice in product and technology strategy. This position is a great opportunity for a smart and ambitious developer to advance their career and have a major impact on a large, important and clean project</p>\n\n<p>JOB QUALIFICATIONS:\nFormal Education, Training, Professional Certification and Work Experience:</p>\n\n<ul>\n<li>BS degree in Computer Science, related technical field or equivalent practical software development experience.</li>\n<li>At least 6 years of software development experience.</li>\n<li>Master of at least one scripting language (e.g., Ruby, Python, etc.) and at least one compiled language (e.g., Java, C/C++).</li>\n<li>Proficient with SQL, relational databases and excellent data modeling skills.</li>\n<li>Good knowledge of at least one frontend framework (e.g., Backbone, Angular, React, etc.).</li>\n</ul>\n\n<p>Preferred Qualifications:</p>\n\n<ul>\n<li>Experience with AWS, Docker and other \u201cdevops\u201d technologies is a plus.</li>\n<li>Strong sense of web design and attuned to the fundamentals of user experience.</li>\n<li>Familiarity with the whole web stack, including protocols and web server optimization techniques.\u00a0</li>\n<li>An understanding of the principles of accessibility and can build products that are accessible to users with disabilities.</li>\n<li>Experience developing \u201cresponsive\u201d websites.</li>\n</ul>\n",
#         "how_to_apply": "<p>Email your resume and a link to your Github profile to <a href=\"mailto:simon.grondin@outlook.com\">simon.grondin@outlook.com</a></p>\n",
#         "id": "f9891adc-be25-11e6-9511-e40bbeeef49d",
#         "location": "Tulsa, OK, USA",
#         "title": "Team Lead, Fullstack Software Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/f9891adc-be25-11e6-9511-e40bbeeef49d"
#     },
#     {
#         "company": "The Nordam Group",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/84d3f7fc-be25-11e6-8246-d8c9aaae18e6.png",
#         "company_url": "http://nordam.com/",
#         "created_at": "Fri Dec 09 15:39:49 UTC 2016",
#         "description": "<p>We\u2019re an independent development team inside The NORDAM Group building a brand new public web service. The aerospace industry we\u2019re modernizing has yet to fully benefit from the data revolution. We pride ourselves on our \u201cstartup\u201d approach: we leverage modern technologies and methodologies and we prefer results over tradition. By being a totally separate unit in a large corporation, we benefit from its support and extensive business network, without all the downsides that come with software development at larger companies.</p>\n\n<p>Our product needs to handle information at scale, safely. We deal with items often worth tens of thousands of dollars or more. We do things the right way from the first time - cutting corners is not worth it in our case.</p>\n\n<p>You know Ruby inside and out, both the pretty and the ugly. You can tell when a piece of code will be inefficient just by looking at it and you know how to optimize it.</p>\n\n<p>However, you are not married to any programming language and would welcome the opportunity to learn a new one on the job with open arms.</p>\n\n<p>As an early dev hire, you will be in a unique position to work on virtually all aspects of our product and have a strong voice in product and technology strategy. This position is a great opportunity for a smart and ambitious developer to advance their career and have a major impact on a large, important and clean project</p>\n\n<p>Job Qualifications:\nFormal Education, Training, Professional Certification and Work Experience:</p>\n\n<ul>\n<li>BS degree in Computer Science, related technical field or equivalent practical software development experience.</li>\n<li>At least 4 years of software development experience.</li>\n<li>Master of at least one scripting language (e.g., Ruby, Python, etc.).</li>\n<li>Proficient with SQL, relational databases and excellent data modeling skills.</li>\n<li>Familiarity with at least one frontend framework (e.g., Backbone, Angular, React, etc.).</li>\n</ul>\n\n<p>Preferred Qualifications:</p>\n\n<ul>\n<li>Experience with AWS, Docker and other \u201cdevops\u201d technologies is a plus.</li>\n<li>Strong sense of UI/UX fundamentals.</li>\n<li>Familiarity with the whole web stack, including protocols and web server optimization techniques.\u00a0</li>\n<li>An understanding of the principles of accessibility and can build products that are accessible to users with disabilities.</li>\n<li>Experience with front end development technologies like HTML5 and CSS3, and experience building responsive websites.</li>\n</ul>\n",
#         "how_to_apply": "<p>Email your resume and a link to your Github profile to <a href=\"mailto:simon.grondin@outlook.com\">simon.grondin@outlook.com</a></p>\n",
#         "id": "8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6",
#         "location": "Tulsa, OK, USA",
#         "title": "Fullstack Developer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6"
#     },
#     {
#         "company": "Make School",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/1a750858-bd92-11e6-86c4-3164e610a489.png",
#         "company_url": "http://www.makeschool.com",
#         "created_at": "Thu Dec 08 22:03:30 UTC 2016",
#         "description": "<p>We&#39;re looking for an iOS Instructor &amp; Curriculum Engineer to develop and teach the iOS curriculum for our Product College.</p>\n\n<p>Make School\u2019s Product College is a 2-year higher education program for aspiring software engineers and founders. Students spend two years learning computer science foundations, software engineering, and product development through a blend of project-based learning and industry experience. Unlike traditional university, students have zero upfront cost for the program; instead they pay tuition through earnings.</p>\n\n<p>Your work will serve as the foundation for the Make School educational experience as we scale from 50 students to 5,000 students and beyond. By joining our team, you\u2019ll be creating the blueprint for the future of higher education.</p>\n\n<p>Our curriculum will be open sourced -- parts are already used by MIT and Carnegie Mellon as well as by tens of thousands of students online. You\u2019ll have the unique opportunity to engage and inspire young software engineers face-to-face as well as to impact those across the world.</p>\n\n<p><strong>What you\u2019ll do:</strong></p>\n\n<ul>\n<li>Extend and customize Make School&#39;s extensive iOS curriculum</li>\n<li>Teach core iOS mobile technologies (Swift, Objective-C)</li>\n<li>Spend 40% of your time time in the classroom, helping students with projects and identifying areas of need</li>\n<li>Spend 30% of your time working with the Curriculum Team building and updating content</li>\n<li>Spend 30% of your time working on open source projects, attending hackathons, building internal tools, etc.</li>\n</ul>\n\n<p><strong>What we&#39;re looking for:</strong></p>\n\n<ul>\n<li>Passion for teaching and mentoring developers</li>\n<li>A strongly held belief that students learn best through guided, hands-on experience</li>\n<li>Industry experience building and maintaining iOS apps, using either Objective-C or Swift</li>\n<li>Strong understanding of development best practices (TDD, version control, design patterns, performance), math principles (calculus and statistics), CS principles (algorithms and data structures), and advanced CS concepts</li>\n<li>A positive impact on the people around you</li>\n</ul>\n\n<p><strong>Become a better developer and teacher:</strong></p>\n\n<ul>\n<li>Receive expert training in research-driven teaching techniques</li>\n<li>Be involved in the development and launch of 50+ apps</li>\n<li>Contribute to open source projects and attend hackathons for free</li>\n<li>Explore the latest tools and technologies</li>\n<li>Teaching is the path to mastery!</li>\n</ul>\n\n<p><strong>Grow your professional network:</strong></p>\n\n<ul>\n<li>Networking opportunities with Make School&#39;s Corporate Partners including LinkedIn, Lyft, and MindBodyOnline</li>\n<li>Our team is a family: join us for regular networking events, city outings, company game nights, etc.</li>\n</ul>\n\n<p><strong>About Make School</strong></p>\n\n<p>Make School was founded in 2012 to empower students to build and ship products that impact their communities. Our core products include:</p>\n\n<ul>\n<li><p>Product College - An accelerated college replacement program for students who want a hands-on and product-oriented educational experience. The program spans two years, divided by a six-month internship at a tech startup. Students learn the Computer Science theory covered by traditional universities paired with the practical experience of building and shipping products, plus soft skills such as ethics, storytelling, and interpersonal communication. The program has no up front cost, and instead students pay tuition through internship and post-grad earnings.</p></li>\n<li><p>Summer Academy - An eight week program where students of all ages build and ship their own iOS app or VR experience. Locations include San Francisco, Sunnyvale, Los Angeles, New York City, Singapore, Taipei, Hong Kong, and Tokyo.</p></li>\n<li><p>S ...
#         "how_to_apply": "<p><a href=\"https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply\">https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply</a></p>\n",
#         "id": "1e8c129c-bd92-11e6-8617-152c7092fed4",
#         "location": "San Francisco",
#         "title": "iOS Instructor and Curriculum Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/1e8c129c-bd92-11e6-8617-152c7092fed4"
#     },
#     {
#         "company": "imo messenger",
#         "company_logo": "http://github-jobs.s3.amazonaws.com/a1d804d0-bce3-11e6-8a7f-9700ffb8862d.png",
#         "company_url": "https://imo.im",
#         "created_at": "Thu Dec 08 01:15:35 UTC 2016",
#         "description": "<p>imo, based in Palo Alto, is a fast growing mobile messaging app. We\u2019re building products that help hundreds of millions of people around the world easily connect with family and friends through text, voice and video chat. </p>\n\n<p>We are currently seeking experienced software engineers to work on our messaging platform. We are growing quickly and are looking for developers who have experience with highly-scalable distributed systems and developers with extensive mobile experience.</p>\n\n<p>Requirements: </p>\n\n<ul>\n<li>BS/MS/PhD in computer science (or the equivalent) </li>\n<li>Strong grasp of data structures and algorithms</li>\n</ul>\n\n<p>Extra credit: </p>\n\n<ul>\n<li>Experience building and designing scalable distributed systems </li>\n<li>Ability to design and implement systems in Java </li>\n<li>Extensive experience writing networking code in C/C++ </li>\n<li>Thorough understanding of TCP/IP and network programming </li>\n<li>Adept at hacking open source software </li>\n<li>1+ years of experience at a company that went through a significant growth stage</li>\n</ul>\n\n<p>Compensation &amp; Perks: </p>\n\n<ul>\n<li>Competitive salary plus $30K starting bonus and stock options </li>\n<li>$500/month housing stipend for living within a five-mile radius of the office </li>\n<li>Four weeks of paid vacation per year (plus paid holidays and sick days) </li>\n<li>401(k), medical, dental and vision benefits </li>\n<li>Access to a concierge medical group </li>\n<li>Catered lunch or dinner daily and a fully-stocked kitchen </li>\n<li>Data plan reimbursement </li>\n<li>Gym membership at Equinox </li>\n<li>Yearly conference stipend </li>\n<li>imo-sponsored team events and outings</li>\n</ul>\n",
#         "how_to_apply": "<p>Email your resume to <a href=\"mailto:jobs@imo.im\">jobs@imo.im</a></p>\n",
#         "id": "bb1644a2-bce3-11e6-9406-ccfe9cedada7",
#         "location": "Palo Alto, CA",
#         "title": "Software Engineer",
#         "type": "Full Time",
#         "url": "http://jobs.github.com/positions/bb1644a2-bce3-11e6-9406-ccfe9cedada7"
#     }
# ]

# %% [markdown]
# ## Assignment
# - Import json and print the whole json response with the json.dumps() function. See what kind of data it contains.
# - Get the dictionary of the first job and call the method keys() to have a better idea of the data at hand.
# - Print some of the first job's content, including images and HTML. You might need to import the IPython package.

# %%
json_response = response.json()
first_job = json_response[0]
first_job.keys()
# Out:
# dict_keys(['id', 'created_at', 'title', 'location', 'type', 'description', 'how_to_apply', 'company', 'company_url', 'company_logo', 'url'])

# %%
from IPython.display import Image
image_url = first_job['company_logo']
Image(url=image_url)
# Out:
# <img src="http://github-jobs.s3.amazonaws.com/012e2336-d389-11e6-867c-d25a8523294d.png"/>

# %%
from IPython.core.display import display, HTML

display(HTML(first_job['description']))
# Out:
# <p>We promise you haven’t worked with anyone <a href="http://www.leadpages.net/careers">like us</a> before.  We’re a Minneapolis / St. Paul, MN based startup that’s changing the way businesses do marketing, lead generation, and conversion rate optimization online.  With a growing team that works closely together, we move fast and enjoy what we do. </p>
#
# <p>As a <strong>Cloud Engineer / Site Reliability Engineer</strong>, you&#39;ll work with a dynamic team to help build out and manage our cloud infrastructure and deployment pipelines. You’ll partner with development teams to build and support tooling - specializing in centralized logging, monitoring and alerting. You will also develop a strong familiarity with all aspects of our overall architecture, including Javascript front-ends, Python API microservices, and Scala-based data science backends. There’s nothing boring about this position!</p>
#
# <p>Come join the fun and build something great with us!</p>
#
# <p><strong>What you’ll do:</strong></p>
#
# <p>Your day-to-day responsibilities will shift and grow but to start with, you will:</p>
#
# <ul>
# <li>Help manage our virtualized cloud infrastructure in the Google Cloud stack: App Engine, Container Engine (Kubernetes), Compute Engine, Cloud Datastore, Cloud Storage, Cloud SQL and BigQuery. Some familiarity with this stack or similar would be amazing!</li>
# <li>Automate application deployment and infrastructure creation processes with Jenkins, Ansible, Packer, Terraform and the Docker toolkit. Again, if you have hands-on experience with these tools or something similar, this could be your jam</li>
# <li>Think laterally and collaborate with other teams to work through tough challenges</li>
# <li>Craft awesome solutions while taking the needs of multiple areas of the organization into account</li>
# <li>Push back and voice your opinion if you think differently from the rest of the team. Yep! We truly value your opinion and we want to hear it</li>
# <li>Work within the fast-paced, lean startup environment, knowing it means we ship early and often.</li>
# <li>Watch what you’ve made help your teammates create awesome customer value. This is what it’s all about!</li>
# </ul>
#
# <p><strong>What you’ve done:</strong></p>
#
# <p>You have a unique combination of skills, talents, and mindset, including:</p>
#
# <ul>
# <li>Experience with building and scaling complex application systems</li>
# <li>A background in scripted provisioning/configuration management tools (think Bash, Ansible, Packer, Terraform, Fabric, and similar)</li>
# <li>Familiarity with Docker and container-based building, deployment, orchestration and service discovery</li>
# <li>Building release pipelines using CI/CD tooling like Jenkins</li>
# <li>Experience with open source monitoring and logging, such as Prometheus, Elasticsearch, Logstash, Kibana and Grafana</li>
# <li>A solid understanding of Unix-like operating systems, Ubuntu/Debian in particular</li>
# <li>Proven development ability; you’re confident with writing and testing robust software</li>
# <li>Strong interpersonal skills and the ability to clearly communicate with both technical and business team members</li>
# </ul>
#
# <p><strong>Who you are:</strong></p>
#
# <ul>
# <li>You are a tech and tooling enthusiast; you love staying up-to-date with the latest solutions for deploying and managing cloud infrastructure</li>
# <li>You build beautifully bulletproof systems that others can depend on, but you also dabble with prototypes and experimental new solutions</li>
# <li>You love improving the intelligence of various systems and environments through the implementation of sturdy and searchable monitoring and centralized logging</li>
# <li>You always look for new things to learn and new ways to leverage your knowledge. You would take great pride in becoming a Subject Matter Expert people can trust</li>
# <li>You have a passion for collaboration with software development teams to work towards the best solution to a need together</li>
# <li>You automate everything! Literally. And you rarely (if ever) manually fix the same problem twice</li>
# <li>You know what “fast-paced” really means and you embrace it</li>
# <li>You never say “That’s not my job”</li>
# </ul>
#
# <p><strong>Who we are:</strong></p>
#
# <p>To learn more about our people, we invite you to visit our <a href="https://www.instagram.com/leadpages/">Instagram</a>, <a href="https://www.facebook.com/LeadpagesCareers/">Facebook</a>, and <a href="http://www.leadpages.net/about/">About</a> pages.</p>
#
# <p>We consider working for a promising startup to be a lifestyle choice rather than a job choice.  Our positions are challenging, but also come with amazing advantages and fulfillment to those who earn them.  If you bring your ‘A game’ to the table, here’s what we’ll bring:</p>
#
# <ul>
# <li>Competitive pay, benefits, and equity.</li>
# <li>2 (yes, two) work-from-home days per week.</li>
# <li>A gorgeous, bright office, conveniently located in Downtown Minneapolis.</li>
# <li>A fully-stocked snack bar and drink fridge to keep you fueled.</li>
# <li>Relocation reimbursement, as needed.  Please note that residence in or relocation to Minneapolis / St. Paul, MN is our one non-negotiable.</li>
# <li>The chance to learn from some of the best people in the business, including <a href="http://blog.leadpages.net/whos-on-your-team-how-leaders-build-dream-teams/">our fiercely compassionate leadership team</a>.</li>
# <li>Career development isn’t just idle chit-chat but a true reality! In 2015, we were thrilled to give promotions to 20% of our stellar employees.</li>
# <li>Challenging and meaningful problems to solve - you will invariably make a difference and impact.</li>
# <li>A vibrant and devoted team, who still finds time for fun.</li>
# <li>No politics, no B.S., and no jerks.</li>
# </ul>
#
# <p>At Leadpages, we strive to create an inclusive workplace that upholds the dignity of all people. We value, respect, and celebrate everyone’s individualities and honor their unique strengths from all different walks of life. We believe that embracing diversity of thought and perspective encourages collaboration that leads to product (and people!) innovation, diverse products and a successful business.</p>
#
# <p><strong>Sound like you?</strong></p>
#
# <p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter explaining why you feel you are a match for this position <a href="http://careers.leadpages.net/apply/YN38C7/Cloud-Engineer-Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>

# %%
display(HTML(first_job['how_to_apply']))
# Out:
# <p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter explaining why you feel you are a match for this position <a href="http://careers.leadpages.net/apply/YN38C7/Cloud-Engineer-Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>

# %% [markdown]
# ## Assignment
# - Import SQLAlchemy and configure a SQLite database.
# - Create 4 tables: company, job, location, github_metadata. Pay sppecial attention on primary and foreign keys as well as unique and non-nullable columns.
# - Make sure you store 'created_at' as a datetime and not a string.

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, ForeignKey, DateTime

engine = create_engine('sqlite:///:memory:', echo=True)
metadata = MetaData()

company_table = Table('company', metadata,
                      Column('id', Integer, primary_key=True),
                      Column('name', String, nullable=False),
                      Column('url', String, unique=True),
                      Column('logo_url', String))

job_table = Table('job', metadata,
                  Column('id', Integer, primary_key=True),
                  Column('company_id', None, ForeignKey('company.id'), nullable=False),
                  Column('type_', Integer),
                  Column('title', String, nullable=False),
                  Column('description', String),
                  Column('how_to_apply', String))

location_table = Table('location', metadata,
                      Column('job_id', None, ForeignKey('job.id'), primary_key=True),
                      Column('description', String),
                      Column('remote_ok', Integer))

github_metadata_table = Table('github_metadata', metadata,
                              Column('job_id', None, ForeignKey('job.id'), primary_key=True),
                              Column('github_id', String, unique=True),
                              Column('url', String, nullable=False),
                              Column('created_at', DateTime, nullable=False))

metadata.create_all(engine)
conn = engine.connect()
# Out:
# 2017-01-06 11:48:36,198 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-01-06 11:48:36,199 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,202 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-01-06 11:48:36,204 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,205 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("company")
# 2017-01-06 11:48:36,206 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,208 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("job")
# 2017-01-06 11:48:36,209 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,211 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("location")
# 2017-01-06 11:48:36,211 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,213 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("github_metadata")
# 2017-01-06 11:48:36,214 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,216 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE company (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	url VARCHAR,
# 	logo_url VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (url)
# )
#
#
# 2017-01-06 11:48:36,217 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,218 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:48:36,220 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE job (
# 	id INTEGER NOT NULL,
# 	company_id INTEGER NOT NULL,
# 	type_ INTEGER,
# 	title VARCHAR NOT NULL,
# 	description VARCHAR,
# 	how_to_apply VARCHAR,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(company_id) REFERENCES company (id)
# )
#
#
# 2017-01-06 11:48:36,220 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,222 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:48:36,223 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE location (
# 	job_id INTEGER NOT NULL,
# 	description VARCHAR,
# 	remote_ok INTEGER,
# 	PRIMARY KEY (job_id),
# 	FOREIGN KEY(job_id) REFERENCES job (id)
# )
#
#
# 2017-01-06 11:48:36,224 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,226 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:48:36,227 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE github_metadata (
# 	job_id INTEGER NOT NULL,
# 	github_id VARCHAR,
# 	url VARCHAR NOT NULL,
# 	created_at DATETIME NOT NULL,
# 	PRIMARY KEY (job_id),
# 	FOREIGN KEY(job_id) REFERENCES job (id),
# 	UNIQUE (github_id)
# )
#
#
# 2017-01-06 11:48:36,228 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:48:36,229 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
from enum import Enum

class JobType(Enum):
    full_time = 1
    part_time = 2

    @staticmethod
    def from_string(string):
        if string.lower() == 'full time' or string.lower() == 'full-time':
            return JobType.full_time
        elif string.lower() == 'part time' or string.lower() == 'part-time':
            return JobType.part_time
        else:
            raise RuntimeError('JobType not supported: {}'.format(string))

# %%
def insert_company(name, url, logo_url, connection=conn):
    """Inserts a new entry in company_table and returns its id."""
    insert = company_table.insert().values(name=name, url=url, logo_url=logo_url)
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
def insert_job(company_id, type_str, title, description, how_to_apply, connection=conn):
    """Inserts a new entry in job_table and returns its id."""
    insert = job_table.insert().values(company_id=company_id, 
                                       type_=JobType.from_string(type_str).value, 
                                       title=title, description=description, how_to_apply=how_to_apply) 
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
def insert_location(job_id, description, connection=conn):
    """Inserts a new entry in location_table and returns its job_id."""
    insert = location_table.insert().values(job_id=job_id, description=description, 
                                       remote_ok=int('remote' in description.lower() 
                                                     or 'telecommute' in description.lower())) 
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
import datetime
created_at_pattern = '%a %b %d %X %Z %Y'

def insert_github_metadata(job_id, github_id, url, created_at_str, connection=conn):
    """Inserts a new entry in github_metadata_table and returns its job_id."""
    insert = github_metadata_table.insert().values(job_id=job_id, github_id=github_id, url=url,
                                       created_at=datetime.datetime.strptime(created_at_str, created_at_pattern))
    result = connection.execute(insert)
    return result.inserted_primary_key[0]

# %%
from sqlalchemy.sql import select

def select_or_insert_company(name, url, logo_url, connection=conn):
    """Returns the company id either by selecting from or inserting in company_table"""
    s = select([company_table]).where(company_table.c.url == url)
    result = connection.execute(s).fetchone()
    if result is not None:
        return result['id']
    else:
        new_id = insert_company(name, url, logo_url, connection)
        return new_id

# %%
def select_or_insert_job(company_name, company_url, company_logo_url, 
                         github_id, github_url, github_created_at_str,
                         type_str, title, description, how_to_apply,
                         location_description):
    """
    Returns the job id either by selecting from or inserting in job_table.
    
    This function might also insert new location, github_metadata and company entries.
    """
    s = select([github_metadata_table]).where(github_metadata_table.c.github_id == github_id)
    result = conn.execute(s).fetchone()
    if result is not None:
        return result['job_id']
    else:
        with engine.begin() as transaction:
            company_id = select_or_insert_company(company_name, company_url, company_logo_url, transaction)
            job_id = insert_job(company_id, type_str, title, description, how_to_apply, transaction)
            insert_github_metadata(job_id, github_id, github_url, github_created_at_str, transaction)
            insert_location(job_id, location_description, transaction)
            
        return job_id

# %%
for job in json_response:
    select_or_insert_job(
        job['company'],
        job['company_url'],
        job['company_logo'],
        job['id'],
        job['url'],
        job['created_at'],
        job['type'],
        job['title'],
        job['description'],
        job['how_to_apply'],
        job['location']
    )
# Out:
# 2017-01-06 11:50:49,551 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,552 INFO sqlalchemy.engine.base.Engine ('806cba3a-d38a-11e6-9b37-19faf2d9fe5b',)
# 2017-01-06 11:50:49,554 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,555 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,556 INFO sqlalchemy.engine.base.Engine ('http://www.leadpages.net/',)
# 2017-01-06 11:50:49,558 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,559 INFO sqlalchemy.engine.base.Engine ('Leadpages', 'http://www.leadpages.net/', 'http://github-jobs.s3.amazonaws.com/012e2336-d389-11e6-867c-d25a8523294d.png')
# 2017-01-06 11:50:49,561 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,562 INFO sqlalchemy.engine.base.Engine (1, 1, 'Cloud Engineer / Site Reliability Engineer', '<p>We promise you haven’t worked with anyone <a href="http://www.leadpages.net/careers">like us</a> before.  We’re a Minneapolis / St. Paul, MN based ... (6330 characters truncated) ... pply/YN38C7/Cloud-Engineer-Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n', '<p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter explaining why you feel you are a match for this ... (49 characters truncated) ... pply/YN38C7/Cloud-Engineer-Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n')
# 2017-01-06 11:50:49,566 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,567 INFO sqlalchemy.engine.base.Engine (1, '806cba3a-d38a-11e6-9b37-19faf2d9fe5b', 'http://jobs.github.com/positions/806cba3a-d38a-11e6-9b37-19faf2d9fe5b', '2017-01-05 21:04:49.000000')
# 2017-01-06 11:50:49,568 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,569 INFO sqlalchemy.engine.base.Engine (1, 'Minneapolis, MN', 0)
# 2017-01-06 11:50:49,570 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,572 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,573 INFO sqlalchemy.engine.base.Engine ('812add76-d37b-11e6-8065-d8a87983108a',)
# 2017-01-06 11:50:49,575 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,576 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,577 INFO sqlalchemy.engine.base.Engine ('http://www.berkeley.edu',)
# 2017-01-06 11:50:49,578 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,580 INFO sqlalchemy.engine.base.Engine ('University of California, Berkeley', 'http://www.berkeley.edu', 'http://github-jobs.s3.amazonaws.com/7a1dae50-d37b-11e6-8a62-e48674991ce0.png')
# 2017-01-06 11:50:49,581 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,582 INFO sqlalchemy.engine.base.Engine (2, 1, 'Data Services Librarian', '<p>POSITION ANNOUNCEMENT\nUNIVERSITY OF CALIFORNIA, BERKELEY</p>\n\n<p>Data Services Librarian\nHiring Range: Associate Librarian to Librarian\n$58,4 ... (8149 characters truncated) ... mailto:librec@library.berkeley.edu">librec@library.berkeley.edu</a></p>\n\n<p><a href="http://apptrkr.com/940483">http://apptrkr.com/940483</a></p>\n', '<p><a href="http://apptrkr.com/940483">http://apptrkr.com/940483</a></p>\n')
# 2017-01-06 11:50:49,584 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,585 INFO sqlalchemy.engine.base.Engine (2, '812add76-d37b-11e6-8065-d8a87983108a', 'http://jobs.github.com/positions/812add76-d37b-11e6-8065-d8a87983108a', '2017-01-05 19:17:40.000000')
# 2017-01-06 11:50:49,589 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,591 INFO sqlalchemy.engine.base.Engine (2, 'Berkeley, CA 94720', 0)
# 2017-01-06 11:50:49,593 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,596 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,598 INFO sqlalchemy.engine.base.Engine ('cdb81090-d291-11e6-9fc6-230a387788dd',)
# 2017-01-06 11:50:49,600 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,601 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,602 INFO sqlalchemy.engine.base.Engine ('https://www.janelia.org/',)
# 2017-01-06 11:50:49,603 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,605 INFO sqlalchemy.engine.base.Engine ('HHMI Janelia Research Campus', 'https://www.janelia.org/', 'http://github-jobs.s3.amazonaws.com/81a49ffc-d291-11e6-9919-6d19904950ce.jpg')
# 2017-01-06 11:50:49,607 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,608 INFO sqlalchemy.engine.base.Engine (3, 1, 'Image Processing Software Developer and Production Engineer (JAVA) Consultant ', '<p>About HHMI:</p>\n\n<pre><code>Howard Hughes Medical Institute (HHMI) is a science philanthropy whose\nmission is to advance biomedical research an ... (3027 characters truncated) ... /li>\n<li> Comfortable working with new programming languages and tools when necessary</li>\n</ul>\n\n<p>HHMI is an Equal Opportunity Employer.</p>\n', '<p>Please apply online at <a href="http://bit.ly/2iPnHKb">http://bit.ly/2iPnHKb</a>.</p>\n')
# 2017-01-06 11:50:49,609 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,611 INFO sqlalchemy.engine.base.Engine (3, 'cdb81090-d291-11e6-9fc6-230a387788dd', 'http://jobs.github.com/positions/cdb81090-d291-11e6-9fc6-230a387788dd', '2017-01-04 16:32:23.000000')
# 2017-01-06 11:50:49,612 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,613 INFO sqlalchemy.engine.base.Engine (3, 'Ashburn, VA', 0)
# 2017-01-06 11:50:49,614 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,616 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,617 INFO sqlalchemy.engine.base.Engine ('4847ca1a-d1c2-11e6-87c7-f7105d23b2fa',)
# 2017-01-06 11:50:49,618 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,620 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,620 INFO sqlalchemy.engine.base.Engine ('http://www.brinkerjobs.com',)
# 2017-01-06 11:50:49,622 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,623 INFO sqlalchemy.engine.base.Engine ('Brinker International', 'http://www.brinkerjobs.com', 'http://github-jobs.s3.amazonaws.com/1c00c4b6-d1c2-11e6-9d77-70a0c115d478.png')
# 2017-01-06 11:50:49,625 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,625 INFO sqlalchemy.engine.base.Engine (4, 1, 'Senior Software Engineer', '<p>Senior Software Engineer  </p>\n\n<p>Dallas, TX (North Dallas) </p>\n\n<p>What does it mean to be a BrinkerHead? We play like a team, take pride i ... (5571 characters truncated) ... \n<p>•Team members enjoy company-wide events and celebrations </p>\n\n<p>•Regular volunteer opportunities with our community give back programs</p>\n', '<p>Email your resume to <a href="mailto:terry.snodgrass@brinker.com">terry.snodgrass@brinker.com</a>.</p>\n')
# 2017-01-06 11:50:49,627 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,628 INFO sqlalchemy.engine.base.Engine (4, '4847ca1a-d1c2-11e6-87c7-f7105d23b2fa', 'http://jobs.github.com/positions/4847ca1a-d1c2-11e6-87c7-f7105d23b2fa', '2017-01-03 14:39:33.000000')
# 2017-01-06 11:50:49,630 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,631 INFO sqlalchemy.engine.base.Engine (4, 'Dallas, Texas', 0)
# 2017-01-06 11:50:49,632 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,633 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,634 INFO sqlalchemy.engine.base.Engine ('98f2edec-d0f9-11e6-8897-553ed26979e3',)
# 2017-01-06 11:50:49,635 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,637 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,637 INFO sqlalchemy.engine.base.Engine ('https://www.paf.com/about-us',)
# 2017-01-06 11:50:49,639 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,640 INFO sqlalchemy.engine.base.Engine ('Paf', 'https://www.paf.com/about-us', 'http://github-jobs.s3.amazonaws.com/71c4e220-d0f9-11e6-982f-8ee5a9eb085a.png')
# 2017-01-06 11:50:49,642 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,643 INFO sqlalchemy.engine.base.Engine (5, 1, 'Senior Database Developer – Oracle PL/SQL', '<p>The Database Development Team at Paf is responsible for the development of data management (including data warehousing) and the BI tools, providin ... (1982 characters truncated) ...  more information about the position, please contact our recruitment partner Arja Martikainen, +358 407621564 or arja.martikainen(at)barona.fi.</p>\n', '<p>Please apply online at <a href="http://bit.ly/2iZLxGd">http://bit.ly/2iZLxGd</a> or email your resume to arja.martikainen(at)barona.fi</p>\n')
# 2017-01-06 11:50:49,644 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,645 INFO sqlalchemy.engine.base.Engine (5, '98f2edec-d0f9-11e6-8897-553ed26979e3', 'http://jobs.github.com/positions/98f2edec-d0f9-11e6-8897-553ed26979e3', '2017-01-02 14:42:36.000000')
# 2017-01-06 11:50:49,647 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,648 INFO sqlalchemy.engine.base.Engine (5, 'Helsinki, Finland', 0)
# 2017-01-06 11:50:49,649 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,651 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,652 INFO sqlalchemy.engine.base.Engine ('e5ed5520-ce19-11e6-91ed-8e7aa8839a6b',)
# 2017-01-06 11:50:49,653 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,654 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,656 INFO sqlalchemy.engine.base.Engine ('http://gram.gs/',)
# 2017-01-06 11:50:49,658 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,658 INFO sqlalchemy.engine.base.Engine ('Gram Games', 'http://gram.gs/', None)
# 2017-01-06 11:50:49,660 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,661 INFO sqlalchemy.engine.base.Engine (6, 1, 'Senior Backend Developer (London, UK)', '<p>Rev up those engines; let’s see what this baby can do. Millions of hits? Psh. You could do that in your sleep.</p>\n\n<p>Essentially...</p>\n\n<p> ... (2319 characters truncated) ... QL, Unity, queues, in-memory caches/databases</p>\n\n<p>...are familiar with development of mobile free-to-play games and mobile best practices</p>\n', '<p><a href="http://grnh.se/8oknja1">http://grnh.se/8oknja1</a></p>\n')
# 2017-01-06 11:50:49,663 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,664 INFO sqlalchemy.engine.base.Engine (6, 'e5ed5520-ce19-11e6-91ed-8e7aa8839a6b', 'http://jobs.github.com/positions/e5ed5520-ce19-11e6-91ed-8e7aa8839a6b', '2016-12-29 22:55:48.000000')
# 2017-01-06 11:50:49,665 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,666 INFO sqlalchemy.engine.base.Engine (6, 'London, UK ', 0)
# 2017-01-06 11:50:49,667 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,669 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,670 INFO sqlalchemy.engine.base.Engine ('8b8135b6-ce19-11e6-991b-57bf66b1b809',)
# 2017-01-06 11:50:49,671 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,672 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,673 INFO sqlalchemy.engine.base.Engine ('http://gram.gs/',)
# 2017-01-06 11:50:49,675 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,676 INFO sqlalchemy.engine.base.Engine (6, 1, 'Senior Developer (London, UK)', '<p>Come on board and develop mind blowing games for millions of players around the planet. What are you waiting for?</p>\n\n<p>Essentially...</p>\n\n ... (2389 characters truncated) ... ..are someone who builds games in their free time, or takes part in recreational game development opportunities such as Game Jams or Hackathons</p>\n', '<p><a href="http://grnh.se/0ogf1d1">http://grnh.se/0ogf1d1</a></p>\n')
# 2017-01-06 11:50:49,678 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,678 INFO sqlalchemy.engine.base.Engine (7, '8b8135b6-ce19-11e6-991b-57bf66b1b809', 'http://jobs.github.com/positions/8b8135b6-ce19-11e6-991b-57bf66b1b809', '2016-12-29 22:53:22.000000')
# 2017-01-06 11:50:49,680 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,680 INFO sqlalchemy.engine.base.Engine (7, 'London, UK ', 0)
# 2017-01-06 11:50:49,682 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,683 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,684 INFO sqlalchemy.engine.base.Engine ('b5a334f2-c914-11e6-91a9-98a048782382',)
# 2017-01-06 11:50:49,685 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,687 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,688 INFO sqlalchemy.engine.base.Engine ('http://www.enzazaden.nl/aboutus/',)
# 2017-01-06 11:50:49,689 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,690 INFO sqlalchemy.engine.base.Engine ('Enza Zaden Beheer B.V.', 'http://www.enzazaden.nl/aboutus/', 'http://github-jobs.s3.amazonaws.com/af433b70-c914-11e6-93d6-c9c4d6d8e9dd.jpg')
# 2017-01-06 11:50:49,692 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,693 INFO sqlalchemy.engine.base.Engine (7, 1, 'Bioinformatician', '<p><strong>Bioinformatician</strong><br />\n<em>Unravelling data</em><br />\n<em>The Netherlands, Enkhuizen &ndash; full time at least at MSc level</ ... (3516 characters truncated) ... us, bio informaticus, bio-informatica</em> <img alt="" src="https://bcontrol.brockmeyer.nl/track.php?orderid=22493" style="height:0;width:0" /></p>\n', '<p><a href="https://ltpx.nl/f1ScFz6" target="_self">Please point your application to the HR department.</a></p>\n')
# 2017-01-06 11:50:49,695 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,696 INFO sqlalchemy.engine.base.Engine (8, 'b5a334f2-c914-11e6-91a9-98a048782382', 'http://jobs.github.com/positions/b5a334f2-c914-11e6-91a9-98a048782382', '2016-12-23 13:43:54.000000')
# 2017-01-06 11:50:49,697 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,698 INFO sqlalchemy.engine.base.Engine (8, 'Enkhuizen', 0)
# 2017-01-06 11:50:49,699 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,701 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,701 INFO sqlalchemy.engine.base.Engine ('f8b12752-c849-11e6-8707-480d66a7fe46',)
# 2017-01-06 11:50:49,703 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,704 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,704 INFO sqlalchemy.engine.base.Engine ('https://squla.redirect.your-jobresponse.com/f/125745/V819/apply',)
# 2017-01-06 11:50:49,706 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,707 INFO sqlalchemy.engine.base.Engine ('Squla', 'https://squla.redirect.your-jobresponse.com/f/125745/V819/apply', 'http://github-jobs.s3.amazonaws.com/f1b17772-c849-11e6-86d1-f29a738c9252.png')
# 2017-01-06 11:50:49,709 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,710 INFO sqlalchemy.engine.base.Engine (8, 1, 'Full Stack Developer', '<p><b>Squla - Full Stack Developer</b><br>\nFull-time in Amsterdam</p>\n\n<p><b>Does the idea of making the world a better place appeal to you?</b><b ... (4729 characters truncated) ...   </i></p>\n\n<p><b><i>Agency calls are not appreciated.</b></p>\n\n<p>Keywords: Vacancy, Fulltime, Parttime, Amsterdam, Developer, Python.</i></p>\n', '<p>You can apply for this position by clicking <b><a href="https://squla.redirect.your-jobresponse.com/full_stack_developer_amsterdam/125745/V819/apply">here</a></b>!</p>\n')
# 2017-01-06 11:50:49,711 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,712 INFO sqlalchemy.engine.base.Engine (9, 'f8b12752-c849-11e6-8707-480d66a7fe46', 'http://jobs.github.com/positions/f8b12752-c849-11e6-8707-480d66a7fe46', '2016-12-22 13:25:17.000000')
# 2017-01-06 11:50:49,714 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,715 INFO sqlalchemy.engine.base.Engine (9, 'Amsterdam', 0)
# 2017-01-06 11:50:49,716 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,717 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,718 INFO sqlalchemy.engine.base.Engine ('fb370efe-c828-11e6-94be-fb480120aa94',)
# 2017-01-06 11:50:49,719 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,721 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,722 INFO sqlalchemy.engine.base.Engine ('http://www.fei.com',)
# 2017-01-06 11:50:49,724 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,725 INFO sqlalchemy.engine.base.Engine ('FEI Company', 'http://www.fei.com', 'http://github-jobs.s3.amazonaws.com/eff9f2f4-c828-11e6-9a8e-f97395899781.jpg')
# 2017-01-06 11:50:49,726 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,727 INFO sqlalchemy.engine.base.Engine (9, 1, 'Software Engineer - Camera team - Transmission electron microscopy', '<p><B>Software Engineer - Camera team - Transmission electron microscopy</p>\n\n<p>The Company, pushing the boundaries of discovery</b><BR>\nWith mor ... (7303 characters truncated) ... nd able to travel.</p>\n\n<p><I>Keywords: Vacancy, fulltime, Eindhoven, IT professionals, Software Developer, Computer Science, Informatics</I></p>\n', '<p><a href="https://feicompany.redirect.your-jobresponse.com/software_engineer_camera_team_transmission_electron_microscopy_eindhoven/125673/V819/apply">Click here for the application form!</a></p>\n')
# 2017-01-06 11:50:49,729 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,735 INFO sqlalchemy.engine.base.Engine (10, 'fb370efe-c828-11e6-94be-fb480120aa94', 'http://jobs.github.com/positions/fb370efe-c828-11e6-94be-fb480120aa94', '2016-12-22 09:29:53.000000')
# 2017-01-06 11:50:49,736 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,737 INFO sqlalchemy.engine.base.Engine (10, 'Eindhoven', 0)
# 2017-01-06 11:50:49,738 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,740 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,742 INFO sqlalchemy.engine.base.Engine ('d8afc95e-c759-11e6-8b92-55c03f089c66',)
# 2017-01-06 11:50:49,743 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,744 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,745 INFO sqlalchemy.engine.base.Engine ('http://www.asml.com',)
# 2017-01-06 11:50:49,747 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,748 INFO sqlalchemy.engine.base.Engine ('ASML', 'http://www.asml.com', 'http://github-jobs.s3.amazonaws.com/b6faf4f0-c759-11e6-98b8-a78c2551b38f.jpg')
# 2017-01-06 11:50:49,750 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,751 INFO sqlalchemy.engine.base.Engine (10, 1, 'Pragmatic Researcher (PhD)', '<p><b>Pragmatic Researcher (PhD)</b></p>\n\n<p><i>Join us in re-shaping the boundaries of science and technology.</i></p>\n\n<p>ASML is always search ... (3831 characters truncated) ... lls are not appreciated.</b></p>\n\n<p>Keywords: Job vacancy, Full-time, Eindhoven, PhD researcher, Science, Technology, Master Class, Starter.</p>\n', '<p><a href="https://asml.redirect.your-jobresponse.com/pragmatic_researcher_phd_veldhoven/125409/V819/apply">Click here to apply</a></p>\n')
# 2017-01-06 11:50:49,753 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,754 INFO sqlalchemy.engine.base.Engine (11, 'd8afc95e-c759-11e6-8b92-55c03f089c66', 'http://jobs.github.com/positions/d8afc95e-c759-11e6-8b92-55c03f089c66', '2016-12-21 08:48:28.000000')
# 2017-01-06 11:50:49,755 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,756 INFO sqlalchemy.engine.base.Engine (11, 'Veldhoven', 0)
# 2017-01-06 11:50:49,758 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,760 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,760 INFO sqlalchemy.engine.base.Engine ('39cd9d66-c62d-11e6-9dec-aa44cc6c99fc',)
# 2017-01-06 11:50:49,762 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,763 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url IS NULL
# 2017-01-06 11:50:49,764 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:50:49,766 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,767 INFO sqlalchemy.engine.base.Engine ('Trusted Autonomy', None, None)
# 2017-01-06 11:50:49,769 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,770 INFO sqlalchemy.engine.base.Engine (11, 1, 'Artificial Intelligence Data Scientist', '<p>No longer the realm of science-fiction, the time is now. Trusted Autonomy is bringing to market the world&#39;s first Artificial General Intellige ... (3393 characters truncated) ... ntic frameworks</li>\n<li>Knowledge of, or experience with, statistical NLP techniques and recommendation/personalization engines\n\xa0</li>\n</ul>\n', '<p>Please apply at <a href="http://beyondlimits.applytojob.com/apply/yVZmgG/Artificial-Intelligence-Data-Scientist">http://beyondlimits.applytojob.com/apply/yVZmgG/Artificial-Intelligence-Data-Scientist</a></p>\n')
# 2017-01-06 11:50:49,771 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,772 INFO sqlalchemy.engine.base.Engine (12, '39cd9d66-c62d-11e6-9dec-aa44cc6c99fc', 'http://jobs.github.com/positions/39cd9d66-c62d-11e6-9dec-aa44cc6c99fc', '2016-12-19 20:54:05.000000')
# 2017-01-06 11:50:49,774 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,775 INFO sqlalchemy.engine.base.Engine (12, 'Los Angeles, CA', 0)
# 2017-01-06 11:50:49,776 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,778 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,779 INFO sqlalchemy.engine.base.Engine ('d92c4c00-c2e4-11e6-8c03-b9aeddd20bd9',)
# 2017-01-06 11:50:49,780 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,782 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,783 INFO sqlalchemy.engine.base.Engine ('https://www.gotcourts.com',)
# 2017-01-06 11:50:49,784 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,785 INFO sqlalchemy.engine.base.Engine ('GotCourts AG', 'https://www.gotcourts.com', 'http://github-jobs.s3.amazonaws.com/d49fa10a-c2e4-11e6-8076-d9635194b35e.png')
# 2017-01-06 11:50:49,787 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,788 INFO sqlalchemy.engine.base.Engine (12, 1, 'Senior Mobile Developer (Android or/and iOS) on site', '<p>Booking a tennis court should be a fast and fun thing to do. With the rise in mobile we now have a better opportunity to make this process even si ... (2117 characters truncated) ... ct on the future of GotCourts and the tennis sport</li>\n</ul>\n\n<p>Possibility to learn new things and grow technically as well as personally</p>\n', '<p>Send your CV to <a href="mailto:cedric.escher@gotcourts.com">cedric.escher@gotcourts.com</a>, we will invite you for a coding challenge :-)</p>\n')
# 2017-01-06 11:50:49,790 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,792 INFO sqlalchemy.engine.base.Engine (13, 'd92c4c00-c2e4-11e6-8c03-b9aeddd20bd9', 'http://jobs.github.com/positions/d92c4c00-c2e4-11e6-8c03-b9aeddd20bd9', '2016-12-15 16:41:41.000000')
# 2017-01-06 11:50:49,794 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,795 INFO sqlalchemy.engine.base.Engine (13, 'Bratislava', 0)
# 2017-01-06 11:50:49,796 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,798 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,798 INFO sqlalchemy.engine.base.Engine ('43a308f0-c2a7-11e6-841e-9215cc8be982',)
# 2017-01-06 11:50:49,799 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,801 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,802 INFO sqlalchemy.engine.base.Engine ('http://www.quintiq.com',)
# 2017-01-06 11:50:49,804 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,805 INFO sqlalchemy.engine.base.Engine ('Quintiq', 'http://www.quintiq.com', 'http://github-jobs.s3.amazonaws.com/0661f5a0-c2a7-11e6-8635-04a4759dd2b3.jpg')
# 2017-01-06 11:50:49,807 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,808 INFO sqlalchemy.engine.base.Engine (13, 1, 'Technical Consultant', '<p><B>Technical Consultant</b><br>\n<I>Philadelphia, United States</i> <p></p>\n\n<p><B>Introduction</b><br>\nQuintiq, part of Dassault Systèmes, is  ... (4758 characters truncated) ... /p>\n\n<p><i>Keywords:Job vacancy, Fulltime, Pennsylvania, USA, Software developer, Software architect, Microsoft SQL Server, Oracle RDBMS.</i></p>\n', '<p><a href="https://quintiqinternational.redirect.your-jobresponse.com/technical_consultant_radnor/124703/V819/solliciteren">Click here to apply!</a></p>\n')
# 2017-01-06 11:50:49,810 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,811 INFO sqlalchemy.engine.base.Engine (14, '43a308f0-c2a7-11e6-841e-9215cc8be982', 'http://jobs.github.com/positions/43a308f0-c2a7-11e6-841e-9215cc8be982', '2016-12-15 09:18:39.000000')
# 2017-01-06 11:50:49,812 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,813 INFO sqlalchemy.engine.base.Engine (14, 'Radnor', 0)
# 2017-01-06 11:50:49,814 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,817 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,817 INFO sqlalchemy.engine.base.Engine ('f18ccdd0-c247-11e6-985c-59a171428a80',)
# 2017-01-06 11:50:49,819 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,820 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,821 INFO sqlalchemy.engine.base.Engine ('http://media.mit.edu',)
# 2017-01-06 11:50:49,822 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,823 INFO sqlalchemy.engine.base.Engine ('Massachusetts Institute of Technology Media Lab', 'http://media.mit.edu', None)
# 2017-01-06 11:50:49,825 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,826 INFO sqlalchemy.engine.base.Engine (14, 1, 'Senior Backend Engineer, Scratch', '<p>We are seeking a curious and motivated software engineer to join our Scratch team at the MIT Media Lab. Scratch (scratch.mit.edu) is a free visual ... (2132 characters truncated) ...  submit a resume and cover letter referencing job no. 13738 at <a href="http://careers.mit.edu">http://careers.mit.edu</a>; keyword is Scratch.</p>\n', '<p>Interested applicants should submit a resume and cover letter referencing job no. 13738 at <a href="http://careers.mit.edu">http://careers.mit.edu</a>; keyword is Scratch.</p>\n')
# 2017-01-06 11:50:49,827 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,829 INFO sqlalchemy.engine.base.Engine (15, 'f18ccdd0-c247-11e6-985c-59a171428a80', 'http://jobs.github.com/positions/f18ccdd0-c247-11e6-985c-59a171428a80', '2016-12-14 21:55:55.000000')
# 2017-01-06 11:50:49,830 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,831 INFO sqlalchemy.engine.base.Engine (15, 'Cambridge, MA', 0)
# 2017-01-06 11:50:49,833 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,834 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,836 INFO sqlalchemy.engine.base.Engine ('a0389ac2-39df-11e6-9bb0-7b3faa3729cc',)
# 2017-01-06 11:50:49,837 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,838 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,840 INFO sqlalchemy.engine.base.Engine ('http://www.kaggle.com',)
# 2017-01-06 11:50:49,841 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,842 INFO sqlalchemy.engine.base.Engine ('Kaggle', 'http://www.kaggle.com', 'http://github-jobs.s3.amazonaws.com/8b90dd46-39df-11e6-9583-738af4d1e73c.png')
# 2017-01-06 11:50:49,843 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,844 INFO sqlalchemy.engine.base.Engine (15, 1, 'Full-Stack Engineer (C#, ASP.NET MVC and React)', '<p>Come help us create the future of Kaggle and in doing so, help shape the future of data science.</p>\n\n<p>As background, Kaggle is best known for ... (3080 characters truncated) ... k from where you&#39;re most productive.</li>\n<li>Stock in a company that has the potential to transform the way data science is done.</li>\n</ul>\n', '<p>Apply here:\n<a href="https://kaggle.applytojob.com/apply/GjSjOi/Fullstack-Engineer?source=Github">https://kaggle.applytojob.com/apply/GjSjOi/Fullstack-Engineer?source=Github</a></p>\n')
# 2017-01-06 11:50:49,846 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,847 INFO sqlalchemy.engine.base.Engine (16, 'a0389ac2-39df-11e6-9bb0-7b3faa3729cc', 'http://jobs.github.com/positions/a0389ac2-39df-11e6-9bb0-7b3faa3729cc', '2016-12-14 05:22:26.000000')
# 2017-01-06 11:50:49,849 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,850 INFO sqlalchemy.engine.base.Engine (16, 'San Francisco or Remote', 1)
# 2017-01-06 11:50:49,851 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,853 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,853 INFO sqlalchemy.engine.base.Engine ('82b27030-c15d-11e6-988b-a3662e7f9df2',)
# 2017-01-06 11:50:49,855 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,856 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,858 INFO sqlalchemy.engine.base.Engine ('http://nygenome.org',)
# 2017-01-06 11:50:49,859 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,860 INFO sqlalchemy.engine.base.Engine ('New York Genome Center', 'http://nygenome.org', None)
# 2017-01-06 11:50:49,862 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,863 INFO sqlalchemy.engine.base.Engine (16, 1, 'DevOps Engineer, Erlich lab', '<p>The Erlich Lab in the New York Genome Center is looking for a highly motivated individual to join our expanding lab. We need creative problem solv ... (2530 characters truncated) ... tting up Continuous Integration infrastructure;\nCloud Monitoring tools (Nagios, Cacti, CloudWatch, Gnaglia, etc.);\nBioinformatics experience.</p>\n', '<p>visit <a href="http://nygenome.org/careers">http://nygenome.org/careers</a></p>\n')
# 2017-01-06 11:50:49,865 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,866 INFO sqlalchemy.engine.base.Engine (17, '82b27030-c15d-11e6-988b-a3662e7f9df2', 'http://jobs.github.com/positions/82b27030-c15d-11e6-988b-a3662e7f9df2', '2016-12-13 17:58:12.000000')
# 2017-01-06 11:50:49,868 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,869 INFO sqlalchemy.engine.base.Engine (17, 'New York, NY', 0)
# 2017-01-06 11:50:49,870 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,871 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,872 INFO sqlalchemy.engine.base.Engine ('d1d69600-c108-11e6-9365-5be7e5886d40',)
# 2017-01-06 11:50:49,874 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,875 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,876 INFO sqlalchemy.engine.base.Engine ('http://www.devicetools.ch',)
# 2017-01-06 11:50:49,877 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,879 INFO sqlalchemy.engine.base.Engine ('Device Tools AG', 'http://www.devicetools.ch', 'http://github-jobs.s3.amazonaws.com/ca21f38c-c108-11e6-88ef-ec978ec6a95d.png')
# 2017-01-06 11:50:49,881 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,882 INFO sqlalchemy.engine.base.Engine (17, 1, 'Software/DevOps Engineer', '<h2>We are looking for an outstanding Software/DevOps Engineer to join our team to help us design, maintain and grow our server and backend infrastru ... (3186 characters truncated) ... ch">contact@devicetools.ch</a> ) and make sure to include links to any projects you worked on, your GitHub or StackOverflow profile or similar.</p>\n', '<p><a href="mailto:contact@devicetools.ch">contact@devicetools.ch</a></p>\n')
# 2017-01-06 11:50:49,883 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,885 INFO sqlalchemy.engine.base.Engine (18, 'd1d69600-c108-11e6-9365-5be7e5886d40', 'http://jobs.github.com/positions/d1d69600-c108-11e6-9365-5be7e5886d40', '2016-12-13 07:51:20.000000')
# 2017-01-06 11:50:49,887 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,888 INFO sqlalchemy.engine.base.Engine (18, 'Zurich', 0)
# 2017-01-06 11:50:49,889 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,890 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,891 INFO sqlalchemy.engine.base.Engine ('f9891adc-be25-11e6-9511-e40bbeeef49d',)
# 2017-01-06 11:50:49,892 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,894 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,895 INFO sqlalchemy.engine.base.Engine ('http://nordam.com/',)
# 2017-01-06 11:50:49,897 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,898 INFO sqlalchemy.engine.base.Engine ('The Nordam Group', 'http://nordam.com/', 'http://github-jobs.s3.amazonaws.com/f53d44ee-be25-11e6-957a-f616239dc5c8.png')
# 2017-01-06 11:50:49,900 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,901 INFO sqlalchemy.engine.base.Engine (18, 1, 'Team Lead, Fullstack Software Developer', '<p>Onsite, Relocation available.</p>\n\n<p>We’re an independent development team inside The NORDAM Group building a brand new public web service. The ... (2489 characters truncated) ... ssibility and can build products that are accessible to users with disabilities.</li>\n<li>Experience developing “responsive” websites.</li>\n</ul>\n', '<p>Email your resume and a link to your Github profile to <a href="mailto:simon.grondin@outlook.com">simon.grondin@outlook.com</a></p>\n')
# 2017-01-06 11:50:49,903 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,904 INFO sqlalchemy.engine.base.Engine (19, 'f9891adc-be25-11e6-9511-e40bbeeef49d', 'http://jobs.github.com/positions/f9891adc-be25-11e6-9511-e40bbeeef49d', '2016-12-09 15:42:07.000000')
# 2017-01-06 11:50:49,906 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,907 INFO sqlalchemy.engine.base.Engine (19, 'Tulsa, OK, USA', 0)
# 2017-01-06 11:50:49,908 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,909 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,910 INFO sqlalchemy.engine.base.Engine ('8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6',)
# 2017-01-06 11:50:49,912 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,913 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,914 INFO sqlalchemy.engine.base.Engine ('http://nordam.com/',)
# 2017-01-06 11:50:49,916 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,918 INFO sqlalchemy.engine.base.Engine (18, 1, 'Fullstack Developer', '<p>We’re an independent development team inside The NORDAM Group building a brand new public web service. The aerospace industry we’re modernizing ha ... (2254 characters truncated) ... ilities.</li>\n<li>Experience with front end development technologies like HTML5 and CSS3, and experience building responsive websites.</li>\n</ul>\n', '<p>Email your resume and a link to your Github profile to <a href="mailto:simon.grondin@outlook.com">simon.grondin@outlook.com</a></p>\n')
# 2017-01-06 11:50:49,919 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,920 INFO sqlalchemy.engine.base.Engine (20, '8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6', 'http://jobs.github.com/positions/8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6', '2016-12-09 15:39:49.000000')
# 2017-01-06 11:50:49,922 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,923 INFO sqlalchemy.engine.base.Engine (20, 'Tulsa, OK, USA', 0)
# 2017-01-06 11:50:49,924 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,926 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,927 INFO sqlalchemy.engine.base.Engine ('1e8c129c-bd92-11e6-8617-152c7092fed4',)
# 2017-01-06 11:50:49,928 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,929 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,930 INFO sqlalchemy.engine.base.Engine ('http://www.makeschool.com',)
# 2017-01-06 11:50:49,931 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,932 INFO sqlalchemy.engine.base.Engine ('Make School', 'http://www.makeschool.com', 'http://github-jobs.s3.amazonaws.com/1a750858-bd92-11e6-86c4-3164e610a489.png')
# 2017-01-06 11:50:49,934 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,935 INFO sqlalchemy.engine.base.Engine (19, 1, 'iOS Instructor and Curriculum Engineer', '<p>We&#39;re looking for an iOS Instructor &amp; Curriculum Engineer to develop and teach the iOS curriculum for our Product College.</p>\n\n<p>Make  ... (3933 characters truncated) ... Principles course framework. Swift CSP is currently being used by high school teachers and computer science clubs around the world.</p></li>\n</ul>\n', '<p><a href="https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply">https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply</a></p>\n')
# 2017-01-06 11:50:49,937 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,938 INFO sqlalchemy.engine.base.Engine (21, '1e8c129c-bd92-11e6-8617-152c7092fed4', 'http://jobs.github.com/positions/1e8c129c-bd92-11e6-8617-152c7092fed4', '2016-12-08 22:03:30.000000')
# 2017-01-06 11:50:49,939 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,940 INFO sqlalchemy.engine.base.Engine (21, 'San Francisco', 0)
# 2017-01-06 11:50:49,941 INFO sqlalchemy.engine.base.Engine COMMIT
# 2017-01-06 11:50:49,943 INFO sqlalchemy.engine.base.Engine SELECT github_metadata.job_id, github_metadata.github_id, github_metadata.url, github_metadata.created_at
# FROM github_metadata
# WHERE github_metadata.github_id = ?
# 2017-01-06 11:50:49,944 INFO sqlalchemy.engine.base.Engine ('bb1644a2-bce3-11e6-9406-ccfe9cedada7',)
# 2017-01-06 11:50:49,945 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-01-06 11:50:49,946 INFO sqlalchemy.engine.base.Engine SELECT company.id, company.name, company.url, company.logo_url
# FROM company
# WHERE company.url = ?
# 2017-01-06 11:50:49,947 INFO sqlalchemy.engine.base.Engine ('https://imo.im',)
# 2017-01-06 11:50:49,949 INFO sqlalchemy.engine.base.Engine INSERT INTO company (name, url, logo_url) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,950 INFO sqlalchemy.engine.base.Engine ('imo messenger', 'https://imo.im', 'http://github-jobs.s3.amazonaws.com/a1d804d0-bce3-11e6-8a7f-9700ffb8862d.png')
# 2017-01-06 11:50:49,952 INFO sqlalchemy.engine.base.Engine INSERT INTO job (company_id, type_, title, description, how_to_apply) VALUES (?, ?, ?, ?, ?)
# 2017-01-06 11:50:49,953 INFO sqlalchemy.engine.base.Engine (20, 1, 'Software Engineer', '<p>imo, based in Palo Alto, is a fast growing mobile messaging app. We’re building products that help hundreds of millions of people around the world ... (1427 characters truncated) ... eimbursement </li>\n<li>Gym membership at Equinox </li>\n<li>Yearly conference stipend </li>\n<li>imo-sponsored team events and outings</li>\n</ul>\n', '<p>Email your resume to <a href="mailto:jobs@imo.im">jobs@imo.im</a></p>\n')
# 2017-01-06 11:50:49,954 INFO sqlalchemy.engine.base.Engine INSERT INTO github_metadata (job_id, github_id, url, created_at) VALUES (?, ?, ?, ?)
# 2017-01-06 11:50:49,955 INFO sqlalchemy.engine.base.Engine (22, 'bb1644a2-bce3-11e6-9406-ccfe9cedada7', 'http://jobs.github.com/positions/bb1644a2-bce3-11e6-9406-ccfe9cedada7', '2016-12-08 01:15:35.000000')
# 2017-01-06 11:50:49,957 INFO sqlalchemy.engine.base.Engine INSERT INTO location (job_id, description, remote_ok) VALUES (?, ?, ?)
# 2017-01-06 11:50:49,958 INFO sqlalchemy.engine.base.Engine (22, 'Palo Alto, CA', 0)
# 2017-01-06 11:50:49,959 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
from sqlalchemy.sql import text

s = text('SELECT * FROM company')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2017-01-06 11:51:20,852 INFO sqlalchemy.engine.base.Engine SELECT * FROM company
# 2017-01-06 11:51:20,854 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 'Leadpages', 'http://www.leadpages.net/', 'http://github-jobs.s3.amazonaws.com/012e2336-d389-11e6-867c-d25a8523294d.png')
#
#  (2, 'University of California, Berkeley', 'http://www.berkeley.edu', 'http://github-jobs.s3.amazonaws.com/7a1dae50-d37b-11e6-8a62-e48674991ce0.png')
#
#  (3, 'HHMI Janelia Research Campus', 'https://www.janelia.org/', 'http://github-jobs.s3.amazonaws.com/81a49ffc-d291-11e6-9919-6d19904950ce.jpg')
#
#  (4, 'Brinker International', 'http://www.brinkerjobs.com', 'http://github-jobs.s3.amazonaws.com/1c00c4b6-d1c2-11e6-9d77-70a0c115d478.png')
#
#  (5, 'Paf', 'https://www.paf.com/about-us', 'http://github-jobs.s3.amazonaws.com/71c4e220-d0f9-11e6-982f-8ee5a9eb085a.png')
#
#  (6, 'Gram Games', 'http://gram.gs/', None)
#
#  (7, 'Enza Zaden Beheer B.V.', 'http://www.enzazaden.nl/aboutus/', 'http://github-jobs.s3.amazonaws.com/af433b70-c914-11e6-93d6-c9c4d6d8e9dd.jpg')
#
#  (8, 'Squla', 'https://squla.redirect.your-jobresponse.com/f/125745/V819/apply', 'http://github-jobs.s3.amazonaws.com/f1b17772-c849-11e6-86d1-f29a738c9252.png')
#
#  (9, 'FEI Company', 'http://www.fei.com', 'http://github-jobs.s3.amazonaws.com/eff9f2f4-c828-11e6-9a8e-f97395899781.jpg')
#
#  (10, 'ASML', 'http://www.asml.com', 'http://github-jobs.s3.amazonaws.com/b6faf4f0-c759-11e6-98b8-a78c2551b38f.jpg')
#
#  (11, 'Trusted Autonomy', None, None)
#
#  (12, 'GotCourts AG', 'https://www.gotcourts.com', 'http://github-jobs.s3.amazonaws.com/d49fa10a-c2e4-11e6-8076-d9635194b35e.png')
#
#  (13, 'Quintiq', 'http://www.quintiq.com', 'http://github-jobs.s3.amazonaws.com/0661f5a0-c2a7-11e6-8635-04a4759dd2b3.jpg')
#
#  (14, 'Massachusetts Institute of Technology Media Lab', 'http://media.mit.edu', None)
#
#  (15, 'Kaggle', 'http://www.kaggle.com', 'http://github-jobs.s3.amazonaws.com/8b90dd46-39df-11e6-9583-738af4d1e73c.png')
#
#  (16, 'New York Genome Center', 'http://nygenome.org', None)
#
#  (17, 'Device Tools AG', 'http://www.devicetools.ch', 'http://github-jobs.s3.amazonaws.com/ca21f38c-c108-11e6-88ef-ec978ec6a95d.png')
#
#  (18, 'The Nordam Group', 'http://nordam.com/', 'http://github-jobs.s3.amazonaws.com/f53d44ee-be25-11e6-957a-f616239dc5c8.png')
#
#  (19, 'Make School', 'http://www.makeschool.com', 'http://github-jobs.s3.amazonaws.com/1a750858-bd92-11e6-86c4-3164e610a489.png')
#
#  (20, 'imo messenger', 'https://imo.im', 'http://github-jobs.s3.amazonaws.com/a1d804d0-bce3-11e6-8a7f-9700ffb8862d.png')

# %%
s = text('SELECT * FROM job')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2017-01-06 11:51:33,062 INFO sqlalchemy.engine.base.Engine SELECT * FROM job
# 2017-01-06 11:51:33,064 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 1, 1, 'Cloud Engineer / Site Reliability Engineer', '<p>We promise you haven’t worked with anyone <a href="http://www.leadpages.net/careers">like us</a> before.  We’re a Minneapolis / St. Paul, MN based ... (6330 characters truncated) ... pply/YN38C7/Cloud-Engineer-Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n', '<p>To apply, please submit your tailored resume, a link to your LinkedIn profile, and a cover letter explaining why you feel you are a match for this ... (49 characters truncated) ... pply/YN38C7/Cloud-Engineer-Site-Reliability-Engineer?source=Github">HERE</a>. Thanks for checking us out - we look forward to hearing from you!</p>\n')
#
#  (2, 2, 1, 'Data Services Librarian', '<p>POSITION ANNOUNCEMENT\nUNIVERSITY OF CALIFORNIA, BERKELEY</p>\n\n<p>Data Services Librarian\nHiring Range: Associate Librarian to Librarian\n$58,4 ... (8149 characters truncated) ... mailto:librec@library.berkeley.edu">librec@library.berkeley.edu</a></p>\n\n<p><a href="http://apptrkr.com/940483">http://apptrkr.com/940483</a></p>\n', '<p><a href="http://apptrkr.com/940483">http://apptrkr.com/940483</a></p>\n')
#
#  (3, 3, 1, 'Image Processing Software Developer and Production Engineer (JAVA) Consultant ', '<p>About HHMI:</p>\n\n<pre><code>Howard Hughes Medical Institute (HHMI) is a science philanthropy whose\nmission is to advance biomedical research an ... (3027 characters truncated) ... /li>\n<li> Comfortable working with new programming languages and tools when necessary</li>\n</ul>\n\n<p>HHMI is an Equal Opportunity Employer.</p>\n', '<p>Please apply online at <a href="http://bit.ly/2iPnHKb">http://bit.ly/2iPnHKb</a>.</p>\n')
#
#  (4, 4, 1, 'Senior Software Engineer', '<p>Senior Software Engineer  </p>\n\n<p>Dallas, TX (North Dallas) </p>\n\n<p>What does it mean to be a BrinkerHead? We play like a team, take pride i ... (5571 characters truncated) ... \n<p>•Team members enjoy company-wide events and celebrations </p>\n\n<p>•Regular volunteer opportunities with our community give back programs</p>\n', '<p>Email your resume to <a href="mailto:terry.snodgrass@brinker.com">terry.snodgrass@brinker.com</a>.</p>\n')
#
#  (5, 5, 1, 'Senior Database Developer – Oracle PL/SQL', '<p>The Database Development Team at Paf is responsible for the development of data management (including data warehousing) and the BI tools, providin ... (1982 characters truncated) ...  more information about the position, please contact our recruitment partner Arja Martikainen, +358 407621564 or arja.martikainen(at)barona.fi.</p>\n', '<p>Please apply online at <a href="http://bit.ly/2iZLxGd">http://bit.ly/2iZLxGd</a> or email your resume to arja.martikainen(at)barona.fi</p>\n')
#
#  (6, 6, 1, 'Senior Backend Developer (London, UK)', '<p>Rev up those engines; let’s see what this baby can do. Millions of hits? Psh. You could do that in your sleep.</p>\n\n<p>Essentially...</p>\n\n<p> ... (2319 characters truncated) ... QL, Unity, queues, in-memory caches/databases</p>\n\n<p>...are familiar with development of mobile free-to-play games and mobile best practices</p>\n', '<p><a href="http://grnh.se/8oknja1">http://grnh.se/8oknja1</a></p>\n')
#
#  (7, 6, 1, 'Senior Developer (London, UK)', '<p>Come on board and develop mind blowing games for millions of players around the planet. What are you waiting for?</p>\n\n<p>Essentially...</p>\n\n ... (2389 characters truncated) ... ..are someone who builds games in their free time, or takes part in recreational game development opportunities such as Game Jams or Hackathons</p>\n', '<p><a href="http://grnh.se/0ogf1d1">http://grnh.se/0ogf1d1</a></p>\n')
#
#  (8, 7, 1, 'Bioinformatician', '<p><strong>Bioinformatician</strong><br />\n<em>Unravelling data</em><br />\n<em>The Netherlands, Enkhuizen &ndash; full time at least at MSc level</ ... (3516 characters truncated) ... us, bio informaticus, bio-informatica</em> <img alt="" src="https://bcontrol.brockmeyer.nl/track.php?orderid=22493" style="height:0;width:0" /></p>\n', '<p><a href="https://ltpx.nl/f1ScFz6" target="_self">Please point your application to the HR department.</a></p>\n')
#
#  (9, 8, 1, 'Full Stack Developer', '<p><b>Squla - Full Stack Developer</b><br>\nFull-time in Amsterdam</p>\n\n<p><b>Does the idea of making the world a better place appeal to you?</b><b ... (4729 characters truncated) ...   </i></p>\n\n<p><b><i>Agency calls are not appreciated.</b></p>\n\n<p>Keywords: Vacancy, Fulltime, Parttime, Amsterdam, Developer, Python.</i></p>\n', '<p>You can apply for this position by clicking <b><a href="https://squla.redirect.your-jobresponse.com/full_stack_developer_amsterdam/125745/V819/apply">here</a></b>!</p>\n')
#
#  (10, 9, 1, 'Software Engineer - Camera team - Transmission electron microscopy', '<p><B>Software Engineer - Camera team - Transmission electron microscopy</p>\n\n<p>The Company, pushing the boundaries of discovery</b><BR>\nWith mor ... (7303 characters truncated) ... nd able to travel.</p>\n\n<p><I>Keywords: Vacancy, fulltime, Eindhoven, IT professionals, Software Developer, Computer Science, Informatics</I></p>\n', '<p><a href="https://feicompany.redirect.your-jobresponse.com/software_engineer_camera_team_transmission_electron_microscopy_eindhoven/125673/V819/apply">Click here for the application form!</a></p>\n')
#
#  (11, 10, 1, 'Pragmatic Researcher (PhD)', '<p><b>Pragmatic Researcher (PhD)</b></p>\n\n<p><i>Join us in re-shaping the boundaries of science and technology.</i></p>\n\n<p>ASML is always search ... (3831 characters truncated) ... lls are not appreciated.</b></p>\n\n<p>Keywords: Job vacancy, Full-time, Eindhoven, PhD researcher, Science, Technology, Master Class, Starter.</p>\n', '<p><a href="https://asml.redirect.your-jobresponse.com/pragmatic_researcher_phd_veldhoven/125409/V819/apply">Click here to apply</a></p>\n')
#
#  (12, 11, 1, 'Artificial Intelligence Data Scientist', '<p>No longer the realm of science-fiction, the time is now. Trusted Autonomy is bringing to market the world&#39;s first Artificial General Intellige ... (3393 characters truncated) ... ntic frameworks</li>\n<li>Knowledge of, or experience with, statistical NLP techniques and recommendation/personalization engines\n\xa0</li>\n</ul>\n', '<p>Please apply at <a href="http://beyondlimits.applytojob.com/apply/yVZmgG/Artificial-Intelligence-Data-Scientist">http://beyondlimits.applytojob.com/apply/yVZmgG/Artificial-Intelligence-Data-Scientist</a></p>\n')
#
#  (13, 12, 1, 'Senior Mobile Developer (Android or/and iOS) on site', '<p>Booking a tennis court should be a fast and fun thing to do. With the rise in mobile we now have a better opportunity to make this process even si ... (2117 characters truncated) ... ct on the future of GotCourts and the tennis sport</li>\n</ul>\n\n<p>Possibility to learn new things and grow technically as well as personally</p>\n', '<p>Send your CV to <a href="mailto:cedric.escher@gotcourts.com">cedric.escher@gotcourts.com</a>, we will invite you for a coding challenge :-)</p>\n')
#
#  (14, 13, 1, 'Technical Consultant', '<p><B>Technical Consultant</b><br>\n<I>Philadelphia, United States</i> <p></p>\n\n<p><B>Introduction</b><br>\nQuintiq, part of Dassault Systèmes, is  ... (4758 characters truncated) ... /p>\n\n<p><i>Keywords:Job vacancy, Fulltime, Pennsylvania, USA, Software developer, Software architect, Microsoft SQL Server, Oracle RDBMS.</i></p>\n', '<p><a href="https://quintiqinternational.redirect.your-jobresponse.com/technical_consultant_radnor/124703/V819/solliciteren">Click here to apply!</a></p>\n')
#
#  (15, 14, 1, 'Senior Backend Engineer, Scratch', '<p>We are seeking a curious and motivated software engineer to join our Scratch team at the MIT Media Lab. Scratch (scratch.mit.edu) is a free visual ... (2132 characters truncated) ...  submit a resume and cover letter referencing job no. 13738 at <a href="http://careers.mit.edu">http://careers.mit.edu</a>; keyword is Scratch.</p>\n', '<p>Interested applicants should submit a resume and cover letter referencing job no. 13738 at <a href="http://careers.mit.edu">http://careers.mit.edu</a>; keyword is Scratch.</p>\n')
#
#  (16, 15, 1, 'Full-Stack Engineer (C#, ASP.NET MVC and React)', '<p>Come help us create the future of Kaggle and in doing so, help shape the future of data science.</p>\n\n<p>As background, Kaggle is best known for ... (3080 characters truncated) ... k from where you&#39;re most productive.</li>\n<li>Stock in a company that has the potential to transform the way data science is done.</li>\n</ul>\n', '<p>Apply here:\n<a href="https://kaggle.applytojob.com/apply/GjSjOi/Fullstack-Engineer?source=Github">https://kaggle.applytojob.com/apply/GjSjOi/Fullstack-Engineer?source=Github</a></p>\n')
#
#  (17, 16, 1, 'DevOps Engineer, Erlich lab', '<p>The Erlich Lab in the New York Genome Center is looking for a highly motivated individual to join our expanding lab. We need creative problem solv ... (2530 characters truncated) ... tting up Continuous Integration infrastructure;\nCloud Monitoring tools (Nagios, Cacti, CloudWatch, Gnaglia, etc.);\nBioinformatics experience.</p>\n', '<p>visit <a href="http://nygenome.org/careers">http://nygenome.org/careers</a></p>\n')
#
#  (18, 17, 1, 'Software/DevOps Engineer', '<h2>We are looking for an outstanding Software/DevOps Engineer to join our team to help us design, maintain and grow our server and backend infrastru ... (3186 characters truncated) ... ch">contact@devicetools.ch</a> ) and make sure to include links to any projects you worked on, your GitHub or StackOverflow profile or similar.</p>\n', '<p><a href="mailto:contact@devicetools.ch">contact@devicetools.ch</a></p>\n')
#
#  (19, 18, 1, 'Team Lead, Fullstack Software Developer', '<p>Onsite, Relocation available.</p>\n\n<p>We’re an independent development team inside The NORDAM Group building a brand new public web service. The ... (2489 characters truncated) ... ssibility and can build products that are accessible to users with disabilities.</li>\n<li>Experience developing “responsive” websites.</li>\n</ul>\n', '<p>Email your resume and a link to your Github profile to <a href="mailto:simon.grondin@outlook.com">simon.grondin@outlook.com</a></p>\n')
#
#  (20, 18, 1, 'Fullstack Developer', '<p>We’re an independent development team inside The NORDAM Group building a brand new public web service. The aerospace industry we’re modernizing ha ... (2254 characters truncated) ... ilities.</li>\n<li>Experience with front end development technologies like HTML5 and CSS3, and experience building responsive websites.</li>\n</ul>\n', '<p>Email your resume and a link to your Github profile to <a href="mailto:simon.grondin@outlook.com">simon.grondin@outlook.com</a></p>\n')
#
#  (21, 19, 1, 'iOS Instructor and Curriculum Engineer', '<p>We&#39;re looking for an iOS Instructor &amp; Curriculum Engineer to develop and teach the iOS curriculum for our Product College.</p>\n\n<p>Make  ... (3933 characters truncated) ... Principles course framework. Swift CSP is currently being used by high school teachers and computer science clubs around the world.</p></li>\n</ul>\n', '<p><a href="https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply">https://jobs.lever.co/makeschool/d87353c7-05b1-4afe-95bf-abb4fb1a8aa8/apply</a></p>\n')
#
#  (22, 20, 1, 'Software Engineer', '<p>imo, based in Palo Alto, is a fast growing mobile messaging app. We’re building products that help hundreds of millions of people around the world ... (1427 characters truncated) ... eimbursement </li>\n<li>Gym membership at Equinox </li>\n<li>Yearly conference stipend </li>\n<li>imo-sponsored team events and outings</li>\n</ul>\n', '<p>Email your resume to <a href="mailto:jobs@imo.im">jobs@imo.im</a></p>\n')

# %%
s = text('SELECT * FROM location')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2017-01-06 11:51:47,957 INFO sqlalchemy.engine.base.Engine SELECT * FROM location
# 2017-01-06 11:51:47,959 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, 'Minneapolis, MN', 0)
#
#  (2, 'Berkeley, CA 94720', 0)
#
#  (3, 'Ashburn, VA', 0)
#
#  (4, 'Dallas, Texas', 0)
#
#  (5, 'Helsinki, Finland', 0)
#
#  (6, 'London, UK ', 0)
#
#  (7, 'London, UK ', 0)
#
#  (8, 'Enkhuizen', 0)
#
#  (9, 'Amsterdam', 0)
#
#  (10, 'Eindhoven', 0)
#
#  (11, 'Veldhoven', 0)
#
#  (12, 'Los Angeles, CA', 0)
#
#  (13, 'Bratislava', 0)
#
#  (14, 'Radnor', 0)
#
#  (15, 'Cambridge, MA', 0)
#
#  (16, 'San Francisco or Remote', 1)
#
#  (17, 'New York, NY', 0)
#
#  (18, 'Zurich', 0)
#
#  (19, 'Tulsa, OK, USA', 0)
#
#  (20, 'Tulsa, OK, USA', 0)
#
#  (21, 'San Francisco', 0)
#
#  (22, 'Palo Alto, CA', 0)

# %%
s = text('SELECT * FROM github_metadata')
result = conn.execute(s)

for row in result:
    print('\n {}'.format(row))
# Out:
# 2017-01-06 11:52:01,307 INFO sqlalchemy.engine.base.Engine SELECT * FROM github_metadata
# 2017-01-06 11:52:01,311 INFO sqlalchemy.engine.base.Engine ()
#
#  (1, '806cba3a-d38a-11e6-9b37-19faf2d9fe5b', 'http://jobs.github.com/positions/806cba3a-d38a-11e6-9b37-19faf2d9fe5b', '2017-01-05 21:04:49.000000')
#
#  (2, '812add76-d37b-11e6-8065-d8a87983108a', 'http://jobs.github.com/positions/812add76-d37b-11e6-8065-d8a87983108a', '2017-01-05 19:17:40.000000')
#
#  (3, 'cdb81090-d291-11e6-9fc6-230a387788dd', 'http://jobs.github.com/positions/cdb81090-d291-11e6-9fc6-230a387788dd', '2017-01-04 16:32:23.000000')
#
#  (4, '4847ca1a-d1c2-11e6-87c7-f7105d23b2fa', 'http://jobs.github.com/positions/4847ca1a-d1c2-11e6-87c7-f7105d23b2fa', '2017-01-03 14:39:33.000000')
#
#  (5, '98f2edec-d0f9-11e6-8897-553ed26979e3', 'http://jobs.github.com/positions/98f2edec-d0f9-11e6-8897-553ed26979e3', '2017-01-02 14:42:36.000000')
#
#  (6, 'e5ed5520-ce19-11e6-91ed-8e7aa8839a6b', 'http://jobs.github.com/positions/e5ed5520-ce19-11e6-91ed-8e7aa8839a6b', '2016-12-29 22:55:48.000000')
#
#  (7, '8b8135b6-ce19-11e6-991b-57bf66b1b809', 'http://jobs.github.com/positions/8b8135b6-ce19-11e6-991b-57bf66b1b809', '2016-12-29 22:53:22.000000')
#
#  (8, 'b5a334f2-c914-11e6-91a9-98a048782382', 'http://jobs.github.com/positions/b5a334f2-c914-11e6-91a9-98a048782382', '2016-12-23 13:43:54.000000')
#
#  (9, 'f8b12752-c849-11e6-8707-480d66a7fe46', 'http://jobs.github.com/positions/f8b12752-c849-11e6-8707-480d66a7fe46', '2016-12-22 13:25:17.000000')
#
#  (10, 'fb370efe-c828-11e6-94be-fb480120aa94', 'http://jobs.github.com/positions/fb370efe-c828-11e6-94be-fb480120aa94', '2016-12-22 09:29:53.000000')
#
#  (11, 'd8afc95e-c759-11e6-8b92-55c03f089c66', 'http://jobs.github.com/positions/d8afc95e-c759-11e6-8b92-55c03f089c66', '2016-12-21 08:48:28.000000')
#
#  (12, '39cd9d66-c62d-11e6-9dec-aa44cc6c99fc', 'http://jobs.github.com/positions/39cd9d66-c62d-11e6-9dec-aa44cc6c99fc', '2016-12-19 20:54:05.000000')
#
#  (13, 'd92c4c00-c2e4-11e6-8c03-b9aeddd20bd9', 'http://jobs.github.com/positions/d92c4c00-c2e4-11e6-8c03-b9aeddd20bd9', '2016-12-15 16:41:41.000000')
#
#  (14, '43a308f0-c2a7-11e6-841e-9215cc8be982', 'http://jobs.github.com/positions/43a308f0-c2a7-11e6-841e-9215cc8be982', '2016-12-15 09:18:39.000000')
#
#  (15, 'f18ccdd0-c247-11e6-985c-59a171428a80', 'http://jobs.github.com/positions/f18ccdd0-c247-11e6-985c-59a171428a80', '2016-12-14 21:55:55.000000')
#
#  (16, 'a0389ac2-39df-11e6-9bb0-7b3faa3729cc', 'http://jobs.github.com/positions/a0389ac2-39df-11e6-9bb0-7b3faa3729cc', '2016-12-14 05:22:26.000000')
#
#  (17, '82b27030-c15d-11e6-988b-a3662e7f9df2', 'http://jobs.github.com/positions/82b27030-c15d-11e6-988b-a3662e7f9df2', '2016-12-13 17:58:12.000000')
#
#  (18, 'd1d69600-c108-11e6-9365-5be7e5886d40', 'http://jobs.github.com/positions/d1d69600-c108-11e6-9365-5be7e5886d40', '2016-12-13 07:51:20.000000')
#
#  (19, 'f9891adc-be25-11e6-9511-e40bbeeef49d', 'http://jobs.github.com/positions/f9891adc-be25-11e6-9511-e40bbeeef49d', '2016-12-09 15:42:07.000000')
#
#  (20, '8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6', 'http://jobs.github.com/positions/8ae1f6bc-be25-11e6-89a1-99b30fbe0cd6', '2016-12-09 15:39:49.000000')
#
#  (21, '1e8c129c-bd92-11e6-8617-152c7092fed4', 'http://jobs.github.com/positions/1e8c129c-bd92-11e6-8617-152c7092fed4', '2016-12-08 22:03:30.000000')
#
#  (22, 'bb1644a2-bce3-11e6-9406-ccfe9cedada7', 'http://jobs.github.com/positions/bb1644a2-bce3-11e6-9406-ccfe9cedada7', '2016-12-08 01:15:35.000000')

# %% [markdown]
# ## Assignment
# - Store the data you got from the API request in the database.
# - Make sure you create a transaction (i.e., if an error occurs while saving a job's location data the database should rollback on all statements regarding that job).

# %% [markdown]
# ## Assignment
# - Execute simple SQL queries in each table and make sure everything looks as was intended.
# - Create queries the following queries:
#     - Find out how many jobs have the phrase "Data Science" and how many have the word "Python" in the description
#     - Find out how many were created in the past 7 days
#     - Find out how are "Remote Ok" and which companies those are with

# %%
s = text("SELECT COUNT() "
         "FROM job")
total, = conn.execute(s).fetchone()

s = text("SELECT COUNT() "
         "FROM job "
         "WHERE description LIKE '%python%'")
python, = conn.execute(s).fetchone()

print("\nThere are {} jobs with the 'Data Science' term, and {}% of them have 'Python' in the description."
      .format(total, 100 * python // total))

from datetime import datetime, timedelta

s = text("SELECT COUNT() "
         "FROM github_metadata "
         "WHERE created_at >= :week_ago")
last_week, = conn.execute(s, week_ago=datetime.today() - timedelta(days=7)
                         ).fetchone()

print("\n{}% of them have been created in the past 7 days."
      .format(100 * last_week // total))
# Out:
# 2017-01-06 11:54:05,963 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM job
# 2017-01-06 11:54:05,965 INFO sqlalchemy.engine.base.Engine ()
# 2017-01-06 11:54:05,967 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM job WHERE description LIKE '%python%'
# 2017-01-06 11:54:05,968 INFO sqlalchemy.engine.base.Engine ()
#
# There are 22 jobs with the 'Data Science' term, and 54% of them have 'Python' in the description.
# 2017-01-06 11:54:05,971 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM github_metadata WHERE created_at >= ?
# 2017-01-06 11:54:05,971 INFO sqlalchemy.engine.base.Engine (datetime.datetime(2016, 12, 30, 11, 54, 5, 970889),)
#
# 22% of them have been created in the past 7 days.

# %%
s = text("SELECT COUNT() "
         "FROM job "
         "JOIN location ON job.id = location.job_id "
         "WHERE remote_ok = :true")
remote_jobs, = conn.execute(s, true=int(True)).fetchone()

if remote_jobs > 0:
    s = text("SELECT name "
             "FROM company "
             "JOIN job ON company.id = job.company_id "
             "JOIN location ON job.id = location.job_id "
             "WHERE location.remote_ok = :true")
    remote_companies = conn.execute(s, true=int(True)).fetchall()
    
    if len(remote_companies) == 1:
        message = '\n{} of those is remote ok. The company with the remote job is: {}'
    else:
        message = '\n{} of those are remote ok. The companies with remote jobs are: {}'
        
    print(message.format(remote_jobs, " ;".join(str(company) for company, in remote_companies)))
# Out:
# 2017-01-06 11:54:24,816 INFO sqlalchemy.engine.base.Engine SELECT COUNT() FROM job JOIN location ON job.id = location.job_id WHERE remote_ok = ?
# 2017-01-06 11:54:24,817 INFO sqlalchemy.engine.base.Engine (1,)
# 2017-01-06 11:54:24,819 INFO sqlalchemy.engine.base.Engine SELECT name FROM company JOIN job ON company.id = job.company_id JOIN location ON job.id = location.job_id WHERE location.remote_ok = ?
# 2017-01-06 11:54:24,820 INFO sqlalchemy.engine.base.Engine (1,)
#
# 1 of those is remote ok. The company with the remote job is: Kaggle

# %%
conn.close()
